# %%
import IPython.display as ipd
ipd.Audio('pia/[pia][cla]1283__1.wav')
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
pip install librosa
# Out:
# Requirement already satisfied: librosa in d:\anaconda3\lib\site-packages (0.7.0)
# Requirement already satisfied: decorator>=3.0.0 in d:\anaconda3\lib\site-packages (from librosa) (4.4.0)
# Requirement already satisfied: soundfile>=0.9.0 in d:\anaconda3\lib\site-packages (from librosa) (0.10.2)
# Requirement already satisfied: numpy>=1.15.0 in d:\anaconda3\lib\site-packages (from librosa) (1.16.4)
# Requirement already satisfied: joblib>=0.12 in d:\anaconda3\lib\site-packages (from librosa) (0.13.2)
# Requirement already satisfied: audioread>=2.0.0 in d:\anaconda3\lib\site-packages (from librosa) (2.1.8)
# Requirement already satisfied: six>=1.3 in d:\anaconda3\lib\site-packages (from librosa) (1.12.0)
# Requirement already satisfied: scipy>=1.0.0 in d:\anaconda3\lib\site-packages (from librosa) (1.2.1)
# Requirement already satisfied: scikit-learn!=0.19.0,>=0.14.0 in d:\anaconda3\lib\site-packages (from librosa) (0.21.1)
# Requirement already satisfied: resampy>=0.2.0 in d:\anaconda3\lib\site-packages (from librosa) (0.2.2)
# Requirement already satisfied: numba>=0.38.0 in d:\anaconda3\lib\site-packages (from librosa) (0.43.1)
# Requirement already satisfied: cffi>=1.0 in d:\anaconda3\lib\site-packages (from soundfile>=0.9.0->librosa) (1.12.3)
# Requirement already satisfied: llvmlite>=0.28.0dev0 in d:\anaconda3\lib\site-packages (from numba>=0.38.0->librosa) (0.28.0)
# Requirement already satisfied: pycparser in d:\anaconda3\lib\site-packages (from cffi>=1.0->soundfile>=0.9.0->librosa) (2.19)
# Note: you may need to restart the kernel to use updated packages.

# %%
#pylab inline
import os
import pandas as pd
import librosa.display
import glob 
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 4))
data, sampling_rate = librosa.load('pia/[pia][cla]1283__1.wav')
librosa.display.waveplot(data, sr=sampling_rate)
