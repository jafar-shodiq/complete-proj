# %%
import requests
import hashlib
import time
import io
import os

from bs4 import BeautifulSoup
from PIL import Image
from selenium import webdriver

# %%
def fetch_image_urls(query:str, max_links_to_fetch:int, wd:webdriver, sleep_between_interactions:int=1):
    def scroll_to_end(wd):
        wd.execute_script('window.scrollTo(0, document.body.scrollHeight);')
        time.sleep(sleep_between_interactions)
        
    # Build te google query
    search_url = 'https://www.google.com/search?safe=off&site=&tbm=isch&source=hp&q={q}&oq={q}&gs_l=img'
    
    # Load the page
    wd.get(search_url.format(q=query))
    
    image_urls = set()
    image_count = 0
    results_start = 0
    while image_count < max_links_to_fetch:
        scroll_to_end(wd)
        
        # Get all image thumbnail results
        thumbnail_results = wd.find_elements_by_css_selector('img.Q4LuWd')
        number_results = len(thumbnail_results)
        
        print(f'Found: {number_results} search results. Extracting links from {results_start}:{number_results}')
        
        for img in thumbnail_results[results_start:number_results]:
            # Try to click every thumbnail such that we can get the real image behind it
            try:
                img.click()
                time.sleep(sleep_between_interactions)
            except Exception:
                continue
                
            # Extract image urls
            actual_images = wd.find_elements_by_css_selector('img.n3VNCb')
            for actual_image in actual_images:
                if actual_image.get_attribute('src') and 'http' in actual_image.get_attribute('src'):
                    image_urls.add(actual_image.get_attribute('src'))
                    
            image_count = len(image_urls)
            
            if len(image_urls) >= max_links_to_fetch:
                print(f'Found: {len(image_urls)} image links, done!')
                break
            
        else:
            print('Found:', len(image_urls), 'image links, looking for more ...')
            time.sleep(30)
            
            load_more_button = wd.find_element_by_css_selector('.mye4qd')
            if load_more_button:
                wd.execute_script("document.querySelector('.mye4qd').click();")
        
        # Move the result startpoint further down
        results_start = len(thumbnail_results)
    
    return image_urls

# %%
def persist_image(folder_path:str, url:str):
    try:
        image_content = requests.get(url).content
        
    except Exception as e:
        print(f'ERROR - Could not download {url} - {e}')
        
    
    try:
        image_file = io.BytesIO(image_content)
        image = Image.open(image_file).convert('RGB')
        file_path = os.path.join(folder_path, hashlib.sha1(image_content).hexdigest()[:10] + '.jpg')
        
        with open(file_path, 'wb') as f:
            image.save(f, 'JPEG', quality=85)
        
        print(f'SUCCESS - saved {url} - as {file_path}')
    
    except Exception as e:
        print(f'ERROR - Could not save {url} - {e}')

# %%
def search_and_download(search_term:str, driver_path:str, target_path:str, number_images:int):
    target_folder = os.path.join(target_path, '_'.join(search_term.lower().split(' ')))
    
    if not os.path.exists(target_folder):
        os.makedirs(target_folder)
        
    with webdriver.Chrome(executable_path=driver_path) as wd:
        res = fetch_image_urls(search_term, number_images, wd=wd, sleep_between_interactions=0.5)
        
    for elem in res:
        persist_image(target_folder, elem)

# %%
driver_path = 'chromedriver'

search_term = 'owen grady'
number_images = 50
target_path = './dataset'

search_and_download(search_term, driver_path, target_path, number_images)
# Out:
# Found: 100 search results. Extracting links from 0:100
# Found: 50 image links, done!
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQiHMJvo_wtDDfzukWsyUEkmXZf-Maj5liZuQ&usqp=CAU - as ./dataset\owen_grady\b35c146280.jpg
# SUCCESS - saved https://pbs.twimg.com/profile_images/611589683986849792/lN6tQUSW_400x400.jpg - as ./dataset\owen_grady\3ff828bfaa.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQyNTPfTtm1ZO1frllJIDv9A_xbPqQPY-7tIg&usqp=CAU - as ./dataset\owen_grady\6bfb1c0b62.jpg
# SUCCESS - saved https://i.pinimg.com/originals/6d/89/8c/6d898c67aa4b914263f0de418fa99f78.png - as ./dataset\owen_grady\84ac82bfbf.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSLeSX3yJgIodGmZJjcgCb1B16WdJNHWBpWpg&usqp=CAU - as ./dataset\owen_grady\5b0b38cbd6.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSa6-AiiEj8o0uhEfwibwIryLZf1DDJX8Tx7A&usqp=CAU - as ./dataset\owen_grady\d41542d5a7.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSCCEPH3pLER5WWhWrT1dB6HDYSb9SDEx2b1g&usqp=CAU - as ./dataset\owen_grady\b647c9c6c0.jpg
# SUCCESS - saved https://images-na.ssl-images-amazon.com/images/I/71hsaiSYzRL._AC_SY879_.jpg - as ./dataset\owen_grady\7c959700f5.jpg
# SUCCESS - saved https://static.wikia.nocookie.net/tsjpfew/images/0/0d/OwenGrady.jpg/revision/latest/top-crop/width/360/height/450?cb=20160508060944 - as ./dataset\owen_grady\88d373fbdd.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRSjX4T4oynsV_vQEhZJYwjPvb6U5u56sqwZQ&usqp=CAU - as ./dataset\owen_grady\6ed100ab2d.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQnMdo6GS8E82RQbvOuLToLL5aX-PC8craTZA&usqp=CAU - as ./dataset\owen_grady\7abe90bef3.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTdfUgzDTRIjxBByG7htTol0kem5oRITkVMfQ&usqp=CAU - as ./dataset\owen_grady\be2e15b851.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcS-53Ant8alX0Cd_2MhdPw63HiMaY3f84VG8w&usqp=CAU - as ./dataset\owen_grady\a80fc18feb.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRGymXbW5cikYXjNb1eizH6VJ71iOtf2b01YA&usqp=CAU - as ./dataset\owen_grady\91bab5c9e6.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcS9fHWG3sYcltoCQMSt3bRdXWxllw3WQI9VUQ&usqp=CAU - as ./dataset\owen_grady\1c45594cbd.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTqwrzfEuBcwtKMCZzdlbrP52OOpMR9BfqdQw&usqp=CAU - as ./dataset\owen_grady\109e121db0.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTsHgNdk8c2uKco3O7FP51_c6PzuDmOpe0a7w&usqp=CAU - as ./dataset\owen_grady\ee99921771.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQTc_H8w7jdRIBvpPk8OYS0k9L5JnF46rj4bg&usqp=CAU - as ./dataset\owen_grady\dd9606225b.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRG47a86MIh7dDpqlGfXiWsGcrcF8yV7DqIRQ&usqp=CAU - as ./dataset\owen_grady\bde4f7109c.jpg
# SUCCESS - saved https://static.wikia.nocookie.net/jurassicpark/images/e/ef/Owen_640x1204.jpg/revision/latest?cb=20200807204032 - as ./dataset\owen_grady\0460f9d269.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTfgHzjGMOr50fac2VpROLvzD1l0B3oh2D2rQ&usqp=CAU - as ./dataset\owen_grady\ca4e0cd159.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTgCeU7vscU4tSYeAecebGCYlVnlI1aWx58hA&usqp=CAU - as ./dataset\owen_grady\3ccca2e4c8.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQapYZlZJCY2GtcXLotEz0z0ApPI8zd-Jkc3g&usqp=CAU - as ./dataset\owen_grady\8dbeab8044.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRBW5XL2MeW-g5m8iXTqx7Ws5a7gLENaPxDhw&usqp=CAU - as ./dataset\owen_grady\8180deecbb.jpg
# SUCCESS - saved https://a1cf74336522e87f135f-2f21ace9a6cf0052456644b80fa06d4f.ssl.cf2.rackcdn.com/images/characters_opt/p-jurassic-world-chris-pratt.jpg - as ./dataset\owen_grady\297829671d.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQNZ1NlpYskHmrUjgEQx2khNEAkD8sDrmqOyA&usqp=CAU - as ./dataset\owen_grady\88672fdc1d.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQ0rph1jgoygPoNauKOu9fBw2nSVBuu6IPW9Q&usqp=CAU - as ./dataset\owen_grady\36a306e0ab.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRla_ICtNPMjpbtpBykMtKZaUjsyHbv0CejhA&usqp=CAU - as ./dataset\owen_grady\99176908d1.jpg
# SUCCESS - saved https://i.redd.it/gwgmenxu9fb11.jpg - as ./dataset\owen_grady\1d8f983a6a.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQaGiHrL_KgRYx3g-fALBqNU7a2TAJzudYt5g&usqp=CAU - as ./dataset\owen_grady\03d03fff32.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRifbD81fMKS6ohDoTM6oXqtvOieVAmSSZrNQ&usqp=CAU - as ./dataset\owen_grady\5a2fe9de48.jpg
# SUCCESS - saved https://64.media.tumblr.com/4f7d6f76df672655f86bef33d16593a0/tumblr_inline_pbs8g0TLzh1uvaxkn_500.gifv - as ./dataset\owen_grady\776956b179.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRRQq3jixtYIG7qrILBTkNdtSTqojCEYHhcFQ&usqp=CAU - as ./dataset\owen_grady\7203c0c972.jpg
# SUCCESS - saved https://static.wikia.nocookie.net/p__/images/f/f7/OwenGrady.png/revision/latest?cb=20150614224946&path-prefix=protagonist - as ./dataset\owen_grady\5edfa30712.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRmqtI6JPKnSfHnc_rrtrN7e9sZw8MqUKHHJg&usqp=CAU - as ./dataset\owen_grady\2a6cf5ee98.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSPsgv5--PJh6aZXtL_HUwBRXxHbU07qHkLoQ&usqp=CAU - as ./dataset\owen_grady\89c0523292.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTX79oSGD7eAuOlzvrIsbBwdF83glzNxSWmWA&usqp=CAU - as ./dataset\owen_grady\763f6acf8e.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcS3rTCun4aIC-S3eYU7Suz0BFo1QaTZIWM38A&usqp=CAU - as ./dataset\owen_grady\54317e370a.jpg
# SUCCESS - saved https://i.pinimg.com/474x/6a/8e/7d/6a8e7d55ae8760403746b168101f387d.jpg - as ./dataset\owen_grady\7b30476ffe.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSTzPgoK-Yonwcqn1-e5uMu_odzlBabKoWdPw&usqp=CAU - as ./dataset\owen_grady\5d80627f2c.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTGZ-2nxwFZHLdYRZk3hm_LPIKnftQRVeiD4w&usqp=CAU - as ./dataset\owen_grady\17052831e8.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRZuymTJa4gbtW__NcWaxPX0f_k51q8s9-ZEA&usqp=CAU - as ./dataset\owen_grady\6a7b5f87ad.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSOR76dDX7Ig5QaQbk3_TbtaYQxpAk2WYqjqw&usqp=CAU - as ./dataset\owen_grady\e72950bce8.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTFL1V6qmSjvZXDN3LtiXUO9OX5cxSIkO-DMw&usqp=CAU - as ./dataset\owen_grady\4540bbc611.jpg
# SUCCESS - saved https://i.ytimg.com/vi/CJq7Qe293DA/maxresdefault.jpg - as ./dataset\owen_grady\20ea88ff05.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRaBFvHlA-6EdFRstoAU-wUYQR_Vfn_Dj_wlw&usqp=CAU - as ./dataset\owen_grady\fa3b5fb154.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQFLllBx_t1-p0OaefnmJJyW_ydXQ6XWzEBNQ&usqp=CAU - as ./dataset\owen_grady\662de4bb91.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQ-wrqCeZOAyuyVOcwx_fJxlhjtwBeqbRRWxQ&usqp=CAU - as ./dataset\owen_grady\af2145f6aa.jpg
# SUCCESS - saved https://cdn.costumewall.com/wp-content/uploads/2015/09/owen-grady-costume-guide.jpg - as ./dataset\owen_grady\4bbb781141.jpg
# SUCCESS - saved https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTFqqAC2rxIQpJpNyfF97iykcEix4e8WUD6cA&usqp=CAU - as ./dataset\owen_grady\6cbb1c32b3.jpg
