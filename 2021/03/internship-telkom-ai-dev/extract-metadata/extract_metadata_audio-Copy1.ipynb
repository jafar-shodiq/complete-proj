# %%
from vad.vad import VoiceActivityDetector
import os
import numpy as np
import glob
import pickle
import warnings; warnings.simplefilter('ignore')

BASE_FILE = 'audio/'
filename = 'Dumbledore asked calmly.wav'

# %%
all_files = glob.glob(BASE_FILE+'*.wav')
dict_vad = {}
for file in all_files:
    dict_vad[file] = webrtcvad.VoiceActivityDetector(file)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-99a9baf02232> in <module>
#       2 dict_vad = {}
#       3 for file in all_files:
# ----> 4     dict_vad[file] = webrtcvad.VoiceActivityDetector(file)
#
# AttributeError: module 'webrtcvad' has no attribute 'VoiceActivityDetector'

# %%
import pickle

# %%
pickle.dump(dict_vad,open('dict_vad','wb'))

# %%
dict_detected_windows = {}
for file in all_files:
    print(file)
    dict_detected_windows[file] = dict_vad[file].detect_speech()

# %%
112530959/16000
# Out:
# 7033.1849375

# %%
detected_windows = v.detect_speech()
print('halo')
# Out:
# /home/user/tryan_workspace/usecases/metadata_usecase/vad/vad.py:149: RuntimeWarning: invalid value encountered in double_scalars
#   speech_ratio = sum_voice_energy/sum_full_energy
# halo

# %%
from matplotlib.pyplot import plot

# %%
detected_windows.shape
# Out:
# (703317, 2)

# %%
data_silent = list(np.array(list(range(detected_windows[:,1].shape[0])))[detected_windows[:,1]<0.1])
data_frame = list(detected_windows[detected_windows[:,1]<0.1,0])

# %%
sound_time = []
last_consecutive_data = -1
for idx,data in enumerate(data_silent):
#     print('halo')
    if (data-1) == last_consecutive_data:
#         print('if')
        last_consecutive_data+=1
    else:
#         print('else')
        sound_time.append(((last_consecutive_data+1),data))
        last_consecutive_data=data

# %%
import scipy.io.wavfile as wf

# %%
v.data[4712*160:4765*160]
# Out:
# array([   63,    67,    70, ..., -7201, -7954, -8284], dtype=int16)

# %%
wf.write('data_1.wav',16000,v.data[10667*16000:10696*16000])
wf.write('data_2.wav',16000,v.data[10752*16000:10774*16000])
wf.write('data_3.wav',16000,v.data[10696*16000:10752*16000])

# %%
agg_time = []
before_time = sound_time[0][1]
first_time_recorded = sound_time[0][0]
for sound in sound_time:
    if (sound[0]-before_time)>50:  #silent selama 700 ms
        agg_time.append((first_time_recorded,before_time))
        first_time_recorded = sound[0]
    before_time = sound[1]

# %%
sound_time
# Out:
# [(4712, 4765),
#  (4807, 4849),
#  (4943, 4996),
#  (5068, 5135),
#  (5148, 5235),
#  (5256, 5559),
#  (6198, 6256),
#  (6304, 6341),
#  (6435, 6490),
#  (6560, 6588),
#  (6592, 6623),
#  (6640, 6726),
#  (6748, 7051),
#  (7688, 7753),
#  (7791, 7837),
#  (7930, 7964),
#  (8214, 8234),
#  (8307, 8407),
#  (8517, 8585),
#  (8662, 8772),
#  (8786, 8873),
#  (8933, 8985),
#  (9000, 9020),
#  (9160, 9182),
#  (9220, 9396),
#  (9430, 9502),
#  (9540, 9683),
#  (9737, 9810),
#  (9864, 9898),
#  (9930, 9952),
#  (9972, 10024),
#  (10105, 10114),
#  (10116, 10133),
#  (10169, 10240),
#  (10254, 10299),
#  (10364, 10389),
#  (10396, 10437),
#  (10471, 10548),
#  (10561, 10628),
#  (10667, 10696),
#  (10752, 10774),
#  (10918, 10928),
#  (10991, 11007),
#  (11067, 11100),
#  (11158, 11186),
#  (11221, 11288),
#  (11312, 11348),
#  (11464, 11470),
#  (11477, 11532),
#  (11535, 11544),
#  (11556, 11559),
#  (11583, 11690),
#  (11707, 11756),
#  (11809, 11855),
#  (12001, 12005),
# ...

# %%
(42706//100)//60 , (42706//100)%60
# Out:
# (7, 7)

# %%
for i in agg_time:
    print((i[1]-i[0])//100, i)
# Out:
# 1 (4712, 4849)
# 0 (4943, 4996)
# 4 (5068, 5559)
# 1 (6198, 6341)
# 0 (6435, 6490)
# 4 (6560, 7051)
# 1 (7688, 7837)
# 0 (7930, 7964)
# 0 (8214, 8234)
# 1 (8307, 8407)
# 0 (8517, 8585)
# 2 (8662, 8873)
# 0 (8933, 9020)
# 5 (9160, 9683)
# 0 (9737, 9810)
# 1 (9864, 10024)
# 1 (10105, 10299)
# 3 (10364, 10696)
# 0 (10752, 10774)
# 0 (10918, 10928)
# 0 (10991, 11007)
# 0 (11067, 11100)
# 1 (11158, 11348)
# 2 (11464, 11756)
# 0 (11809, 11855)
# 0 (12001, 12005)
# 1 (12062, 12162)
# 1 (12216, 12381)
# 0 (12523, 12591)
# 1 (12699, 12849)
# 0 (12928, 12954)
# 3 (13113, 13467)
# 8 (13520, 14411)
# 1 (14486, 14621)
# 2 (14756, 14973)
# 9 (15074, 15978)
# 5 (16117, 16650)
# 0 (16749, 16807)
# 2 (16865, 17100)
# 1 (17181, 17308)
# 3 (17364, 17683)
# 0 (17740, 17788)
# 5 (17857, 18370)
# 0 (18430, 18475)
# 9 (18561, 19553)
# 0 (19669, 19752)
# 6 (19852, 20469)
# 2 (20567, 20831)
# 1 (21342, 21497)
# 0 (21590, 21617)
# 0 (21728, 21787)
# 0 (21850, 21896)
# 0 (22154, 22180)
# 1 (22256, 22427)
# ...

# %%
data_silent[4700:]
# Out:
# [4700,
#  4701,
#  4702,
#  4703,
#  4704,
#  4705,
#  4706,
#  4707,
#  4708,
#  4709,
#  4710,
#  4711,
#  4765,
#  4766,
#  4767,
#  4768,
#  4769,
#  4770,
#  4771,
#  4772,
#  4773,
#  4774,
#  4775,
#  4776,
#  4777,
#  4778,
#  4779,
#  4780,
#  4781,
#  4782,
#  4783,
#  4784,
#  4785,
#  4786,
#  4787,
#  4788,
#  4789,
#  4790,
#  4791,
#  4792,
#  4793,
#  4794,
#  4795,
#  4796,
#  4797,
#  4798,
#  4799,
#  4800,
#  4801,
#  4802,
#  4803,
#  4804,
#  4805,
#  4806,
#  4849,
#  4850,
#  4851,
#  4852,
#  4853,
#  4854,
#  4855,
#  4856,
#  4857,
#  4858,
#  4859,
#  4860,
#  4861,
#  4862,
#  4863,
#  4864,
#  4865,
#  4866,
#  4867,
#  4868,
#  4869,
#  4870,
#  4871,
#  4872,
#  4873,
#  4874,
#  4875,
#  4876,
#  4877,
#  4878,
#  4879,
#  4880,
#  4881,
#  4882,
#  4883,
#  4884,
#  4885,
#  4886,
#  4887,
#  4888,
#  4889,
#  4890,
#  4891,
#  4892,
#  4893,
#  4894,
#  4895,
#  4896,
#  4897,
#  4898,
#  4899,
#  4900,
#  4901,
#  4902,
#  4903,
#  4904,
#  4905,
# ...

# %%
len(data_silent)
# Out:
# 26198

# %%
data_frame
# Out:
# [0.0,
#  160.0,
#  320.0,
#  480.0,
#  640.0,
#  800.0,
#  960.0,
#  1120.0,
#  1280.0,
#  1440.0,
#  1600.0,
#  1760.0,
#  1920.0,
#  2080.0,
#  2240.0,
#  2400.0,
#  2560.0,
#  2720.0,
#  2880.0,
#  3040.0,
#  3200.0,
#  3360.0,
#  3520.0,
#  3680.0,
#  3840.0,
#  4000.0,
#  4160.0,
#  4320.0,
#  4480.0,
#  4640.0,
#  4800.0,
#  4960.0,
#  5120.0,
#  5280.0,
#  5440.0,
#  5600.0,
#  5760.0,
#  5920.0,
#  6080.0,
#  6240.0,
#  6400.0,
#  6560.0,
#  6720.0,
#  6880.0,
#  7040.0,
#  7200.0,
#  7360.0,
#  7520.0,
#  7680.0,
#  7840.0,
#  8000.0,
#  8160.0,
#  8320.0,
#  8480.0,
#  8640.0,
#  8800.0,
#  8960.0,
#  9120.0,
#  9280.0,
#  9440.0,
#  9600.0,
#  9760.0,
#  9920.0,
#  10080.0,
#  10240.0,
#  10400.0,
#  10560.0,
#  10720.0,
#  10880.0,
#  11040.0,
#  11200.0,
#  11360.0,
#  11520.0,
#  11680.0,
#  11840.0,
#  12000.0,
#  12160.0,
#  12320.0,
#  12480.0,
#  12640.0,
#  12800.0,
#  12960.0,
#  13120.0,
#  13280.0,
#  13440.0,
#  13600.0,
#  13760.0,
#  13920.0,
#  14080.0,
# ...

# %%
np.array(list(range(detected_windows[:,0].shape[0])))
# Out:
# array([ True, False, False, ..., False, False, False])

# %% [markdown]
# # AFTER DATA GATHERED

# %%
from vad.vad import VoiceActivityDetector
import os
import scipy.io.wavfile as wf
import numpy as np
import glob
import pickle
import requests
import warnings; warnings.simplefilter('ignore')


def user_auth():
    url = "https://10.201.2.21:80/users/authenticate"

    payload='email=lukedaely%40gmail.com&password=testesttest'
    headers = {
      'Content-Type': 'application/x-www-form-urlencoded'
    }

    response = requests.request("POST", url, headers=headers, data=payload, verify=False)
    response = response.json()
    if response['status'] == 200:
        return {'status':response['status'],'token':response['data']['token']}
    else:
        return {'status':response['status']}
def upload_data(audio_file_name,token):
    url = "https://10.201.2.21:80/audios"

    payload={}
    files=[
      ('file',(audio_file_name.split('/')[-1],open(audio_file_name,'rb'),'audio/mpeg'))
    ]
    headers = {
      'x-access-token': token
    }

    response = requests.request("POST", url, headers=headers, data=payload, files=files,verify=False)
    response = response.json()
    return {'status':response['status'],'message':response['message']}

def inference_data(audio_file_name,token):
    url = "https://10.201.2.21:80/audios/infer"

    payload={'filename': audio_file_name.split('/')[-1]}
    files=[

    ]
    headers = {
      'x-access-token': token
    }

    response = requests.request("POST", url, headers=headers, data=payload, files=files, verify=False)
    response = response.json()
    if response['status'] == 200:
        return {'status':response['status'],'transcript':response['data']['transcript']}
    else:
        return {'status':response['status']}

def stt_api(file):
    
    result_1 = user_auth()
    if result_1['status']!=200:
        print(1)
        return {'status':result_1['status']}
    result_2 = upload_data(file,result_1['token'])
    if result_2['status']!=200:
        print(2)
        return {'status':result_2['status']}    
    result_3 = inference_data(file,result_1['token'])
    if result_3['status']!=200:
        print(3)
        return {'status':result_3['status']}
    return result_3


BASE_FILE = 'data/audio/'
filename = 'Design Thinking for Career Planning and Development.wav'

# %%
data = pickle.load(open('dict_detected_windows','rb'))

# %%
data.keys()
# Out:
# dict_keys(['data/audio/Design Thinking for Career Planning and Development.wav', 'data/audio/How to Cope with WFH Challenges for Leader & Member.wav', 'data/audio/Stay Productive While Remote Working With Scrum Implementation.wav', 'data/audio/Digitalisasi UMKM dengan BONUM POS.wav', 'data/audio/Nabung Pangkal Kaya Yakin!!!.wav', 'data/audio/Managing Offline Mode in Android Its Easier Than You Think!.wav', 'data/audio/Wellness at Home during WFH.wav', 'data/audio/Use API to Accelerate The Making of Your Ideas.wav', 'data/audio/Polines Terkesan dengan Infrastruktur Lab DDS.wav', 'data/audio/A Way of Creating Social Media Persona.wav', 'data/audio/How to Increase Code Quality with Clean Code on Android.wav', 'data/audio/How to Get Your Product Being Adopted and Used by the User.wav', 'data/audio/Empati Kepada Pelanggan.wav', 'data/audio/Infrastruktur FTTH (Fiber to the Home) Bawah Tanah (Under-Ground).wav', 'data/audio/Robotic Process Automation (RPA) for Next Generation of Indonesia.w
# ...

# %%
all_response_stt_dict = {}
for file_name_audio_data in data.keys():
    print(file_name_audio_data)
    detected_windows = data[file_name_audio_data]
    data_silent = list(np.array(list(range(detected_windows[:,1].shape[0])))[detected_windows[:,1]<0.1])
    data_frame = list(detected_windows[detected_windows[:,1]<0.1,0])

    sound_time = []
    last_consecutive_data = -1
    for idx,data_sil in enumerate(data_silent):
    #     print('halo')
        if (data_sil-1) == last_consecutive_data:
    #         print('if')
            last_consecutive_data+=1
        else:
    #         print('else')
            sound_time.append(((last_consecutive_data+1),data_sil))
            last_consecutive_data=data_sil
    agg_time = []
    before_time = sound_time[0][1]
    first_time_recorded = sound_time[0][0]
    for sound in sound_time:
        if (sound[0]-before_time)>120:  #silent selama 700 ms

            agg_time.append((first_time_recorded,before_time))

            first_time_recorded = sound[0]

        elif (sound[0]-before_time)>80: #silent slama 500 ms

            if (sound[0] - first_time_recorded)>1000: #duration already beyond 10 seconds
                agg_time.append((first_time_recorded,before_time))
                first_time_recorded = sound[0]
        elif (sound[0]-before_time)>30:
            if (sound[0] - first_time_recorded)>1500: #duration already beyond 15 seconds
                agg_time.append((first_time_recorded,before_time))

                first_time_recorded = sound[0]




        before_time = sound[1]

    voice_data = VoiceActivityDetector(file_name_audio_data)
    all_response_stt = []
    for i in range(len(agg_time)):
        wf.write('temp_data/example.wav',16000,voice_data.data[agg_time[i][0]*160 : agg_time[i][1]*160])
        time.sleep(1)
        response = stt_api('temp_data/example.wav')
        if response['status']!=200:
            all_response_stt.append((agg_time[i][0],agg_time[i][1],'(404)'))
        else:
            all_response_stt.append((agg_time[i][0],agg_time[i][1],response['transcript']))
        if i%20==0:
            print(i)
    all_response_stt_dict[file_name_audio_data] = all_response_stt
# Out:
# data/audio/Design Thinking for Career Planning and Development.wav
# 0
# 20
# 40
# 60
# 80
# 100
# 120
# 3
# 140
# 160
# 180
# 200
# 220
# 240
# 260
# 280
# 300
# 320
# 340
# 360
# 380
# 400
# 420
# 3
# data/audio/How to Cope with WFH Challenges for Leader & Member.wav
# 0
# 20
# 40
# 60
# 80
# 3
# 100
# 120
# 140
# 160
# 3
# 180
# 200
# 220
# 240
# 260
# 280
# 300
# 320
# 340
# 360
# 3
# 380
# 400
# 420
# 440
# 460
# 480
# 500
# 3
# 520
# 540
# 560
# 580
# 600
# 620
# 640
# 660
# 680
# 700
# 720
# 740
# 3
# 760
# 3
# data/audio/Stay Productive While Remote Working With Scrum Implementation.wav
# 0
# 3
# 20
# 3
# 40
# 60
# 80
# 3
# 100
# 120
# 140
# 3
# 160
# 3
# 180
# 3
# 200
# 220
# 3
# 240
# 3
# 3
# 260
# 3
# 280
# 300
# 3
# 320
# 3
# 340
# 3
# 360
# 3
# 380
# 3
# 3
# 400
# 3
# 3
# 420
# 440
# 3
# 3
# 460
# 3
# 480
# 500
# 520
# 540
# 560
# 580
# 600
# 620
# 640
# 660
# 680
# 3
# 700
# 720
# 740
# 760
# 780
# 3
# 800
# 820
# 840
# data/audio/Digitalisasi UMKM dengan BONUM POS.wav
# ...

# %%
all_response_stt_dict['data/audio/Design Thinking for Career Planning and Development.wav']
# Out:
# [(264, 1117, ''),
#  (1764, 2184, ''),
#  (2311, 2342, ''),
#  (2475, 2877, 'dan '),
#  (3229, 3618, ''),
#  (4266, 4684, ''),
#  (4818, 4841, ''),
#  (4972, 5399, 'oh '),
#  (5763, 6121, 'datang '),
#  (7046,
#   9357,
#   'assalamualaikum wabarakatu semangat pagi pagi pagi pagi bersyukur lagi di acara apa kabar semua yang ada di kantor rumah atau dimana manapun kalian berada semoga saat selalu ya dan tetap produktif pastinya di masa sistem seperti saat ini '),
#  (9428,
#   10831,
#   'perkenalkan saya tanya dari yang akanndu acara dari hari ini topik kali ini udah kalah serunyaan nih dengan topik topik sebelumnya kali ini kita akan membahas tentanggaring '),
#  (10916,
#   13943,
# ...

# %%
pickle.dump(all_response_stt_dict,open('all_response_stt','wb'))

# %%
all_response_stt_dict.keys()
# Out:
# dict_keys(['data/audio/Design Thinking for Career Planning and Development.wav', 'data/audio/How to Cope with WFH Challenges for Leader & Member.wav', 'data/audio/Stay Productive While Remote Working With Scrum Implementation.wav', 'data/audio/Digitalisasi UMKM dengan BONUM POS.wav', 'data/audio/Nabung Pangkal Kaya Yakin!!!.wav', 'data/audio/Managing Offline Mode in Android Its Easier Than You Think!.wav', 'data/audio/Wellness at Home during WFH.wav', 'data/audio/Use API to Accelerate The Making of Your Ideas.wav', 'data/audio/Polines Terkesan dengan Infrastruktur Lab DDS.wav', 'data/audio/A Way of Creating Social Media Persona.wav', 'data/audio/How to Increase Code Quality with Clean Code on Android.wav', 'data/audio/How to Get Your Product Being Adopted and Used by the User.wav', 'data/audio/Empati Kepada Pelanggan.wav', 'data/audio/Infrastruktur FTTH (Fiber to the Home) Bawah Tanah (Under-Ground).wav', 'data/audio/Robotic Process Automation (RPA) for Next Generation of Indonesia.w
# ...

# %%
len(agg_time)

# %%
BASE_FILE = 'data/audio/'
filename = 'Accelerate Your Workflows With Secured Digital Signature.wav'
voice_data = VoiceActivityDetector(BASE_FILE+filename)
all_response_stt = []
for i in range(len(agg_time)):
    wf.write('temp_data/example.wav',16000,voice_data.data[agg_time[i][0]*160 : agg_time[i][1]*160])
#     time.sleep(2)
    response = stt_api('temp_data/example.wav')
    if response['status']!=200:
        all_response_stt.append((agg_time[i][0],agg_time[i][1],'(404)'))
    else:
        all_response_stt.append((agg_time[i][0],agg_time[i][1],response['transcript']))
    if i%20==0:
        print(i)
# Out:
# 0
# 20
# 40
# 60
# 80
# 100
# 120
# 140
# 160
# 180
# 200
# 3
# 3
# 220
# 3
# 240
# 3
# 3
# 260
# 3
# 280
# 300
# 3
# 320
# 3
# 3
# 340
# 3
# 360
# 3
# 380
# 3
# 400
# 420
# 440
# 3
# 460
# 3
# 3
# 480
# 500
# 3
# 520
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-170-cda667f43392> in <module>
#       6     wf.write('temp_data/example.wav',16000,voice_data.data[agg_time[i][0]*160 : agg_time[i][1]*160])
#       7 #     time.sleep(2)
# ----> 8     response = stt_api('temp_data/example.wav')
#       9     if response['status']!=200:
#      10         all_response_stt.append((agg_time[i][0],agg_time[i][1],'(404)'))
#
# <ipython-input-143-c35135e030c7> in stt_api(file)
#      59         print(2)
#      60         return {'status':result_2['status']}
# ---> 61     result_3 = inference_data(file,result_1['token'])
#      62     if result_3['status']!=200:
# ...

# %%
len(all_response_stt)
# Out:
# 623

# %%
all_response_stt[100]
# Out:
# (88667,
#  89685,
#  'pada tangan alat elektronik atau tp yang sertifikasi dibuat anak elektronik ')

# %% [markdown]
# # API STT

# %%
# Out:
# /home/user/miniconda3/envs/py38/lib/python3.8/site-packages/urllib3/connectionpool.py:981: InsecureRequestWarning: Unverified HTTPS request is being made to host '10.201.2.21'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /home/user/miniconda3/envs/py38/lib/python3.8/site-packages/urllib3/connectionpool.py:981: InsecureRequestWarning: Unverified HTTPS request is being made to host '10.201.2.21'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# {'status': 200, 'transcript': 'apa di ada kerja sama dengan ini ada tersendiri '}
# ...

# %%
stt_api('example.wav')
# Out:
# /home/user/miniconda3/envs/py38/lib/python3.8/site-packages/urllib3/connectionpool.py:981: InsecureRequestWarning: Unverified HTTPS request is being made to host '10.201.2.21'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /home/user/miniconda3/envs/py38/lib/python3.8/site-packages/urllib3/connectionpool.py:981: InsecureRequestWarning: Unverified HTTPS request is being made to host '10.201.2.21'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /home/user/miniconda3/envs/py38/lib/python3.8/site-packages/urllib3/connectionpool.py:981: InsecureRequestWarning: Unverified HTTPS request is being made to host '10.201.2.21'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# ...

# %%
result_3
# Out:
# {'status': 200,
#  'transcript': 'paling dari saya bagaimana supaya kita semua bisa menerapkan '}

# %%
result_1
# Out:
# {'status': 200,
#  'token': 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpZCI6IjYwNjQ4ODkwNWNhZjQxMDU4MTUzNDUzZCIsImlhdCI6MTYxOTQxODg4NSwiZXhwIjoxNjE5NDE5NDg1fQ.KNjz-uJfyM_NZox5icmwnczu9Sfjhh52vCzwq9gW4y0'}

# %%
import requests

url = "https://10.201.2.21:80/audios/infer"

payload={'filename': 'example.wav'}
files=[

]
headers = {
  'x-access-token': 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpZCI6IjYwNjQ4ODkwNWNhZjQxMDU4MTUzNDUzZCIsImlhdCI6MTYxOTQxODg4NSwiZXhwIjoxNjE5NDE5NDg1fQ.KNjz-uJfyM_NZox5icmwnczu9Sfjhh52vCzwq9gW4y0'
}

response = requests.request("POST", url, headers=headers, data=payload, files=files, verify=False)

print(response.text)
# Out:
# {"type":"success","status":200,"message":"Transcript success","data":{"transcript":"personal lebih fokus dari individu atau mengikuti mengikuti jobtri dan kompetisi untuk share pekerjaan sangat dibutuhkantentukan oleh perusahaan "}}
# /home/user/miniconda3/envs/py38/lib/python3.8/site-packages/urllib3/connectionpool.py:981: InsecureRequestWarning: Unverified HTTPS request is being made to host '10.201.2.21'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
