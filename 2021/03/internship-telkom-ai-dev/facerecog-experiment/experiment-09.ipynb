# %%
import face_recognition
import cv2
import os
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from timeit import default_timer as timer
from imutils import paths

# %%
knownEncodings = []
knownNames = []

# %%
start = timer()
imagePaths = list(paths.list_images('dataset-1'))
tempNames = []

for (i, imagePath) in enumerate(imagePaths):
    name = imagePath.split(os.path.sep)[-1].split('.')[0]
    tempNames.append(name)

for x in filter(lambda w: w not in knownNames, tempNames):
    print('Processing...')
    image = cv2.imread(imagePath)
    rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    boxes = face_recognition.face_locations(rgb, model='hog')
    encodings = face_recognition.face_encodings(rgb, known_face_locations=boxes)
    
    for encoding in encodings:
        knownEncodings.append(encoding)
        knownNames.append(x)

knownNames = list(dict.fromkeys(tempNames))

print(f'Time: {timer()-start}')
print(knownNames)
print(len(knownEncodings))
# Out:
# Time: 0.0023443000000042957
# ['billgates_01', 'billgates_02', 'drphil_01', 'elonmusk_01', 'jackma_01']
# 5

# %%
test = face_recognition.load_image_file('stevejobs_01.jpg')
test = cv2.cvtColor(test, cv2.COLOR_BGR2RGB)
encode_test = face_recognition.face_encodings(test)[0]

# %%
img = mpimg.imread('stevejobs_01.jpg')
plt.figure(figsize=(5, 5))
plt.axis('off')
plt.imshow(img)

# %%
knownEncodings = []
knownNames = []

# %%
start = timer()
imagePaths = list(paths.list_images('dataset-1'))
tempNames = []

for (i, imagePath) in enumerate(imagePaths):
    name = imagePath.split(os.path.sep)[-1].split('.')[0]
    tempNames.append(name)

for x in filter(lambda w: w not in knownNames, tempNames):
    print('Processing...')
    image = cv2.imread(imagePath)
    rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    boxes = face_recognition.face_locations(rgb, model='hog')
    encodings = face_recognition.face_encodings(rgb, known_face_locations=boxes)
    
    for encoding in encodings:
        knownEncodings.append(encoding)
        knownNames.append(x)

knownNames = list(dict.fromkeys(tempNames))

print(f'Time: {timer()-start}')
print(knownNames)
print(len(knownNames))
# Out:
# Processing...
# Processing...
# Processing...
# Processing...
# Processing...
# Time: 7.321832299999983
# ['billgates_01', 'billgates_02', 'drphil_01', 'elonmusk_01', 'jackma_01']
# 5

# %%
test = face_recognition.load_image_file('stevejobs_01.jpg')
test = cv2.cvtColor(test, cv2.COLOR_BGR2RGB)
encode_test = face_recognition.face_encodings(test)[0]

# %%
result = face_recognition.compare_faces(knownEncodings, encode_test)
result
# Out:
# [False, False, False, False, False]

# %%
test = face_recognition.load_image_file('elon_musk_test.jpg')
test = cv2.cvtColor(test, cv2.COLOR_BGR2RGB)
encode_test = face_recognition.face_encodings(test)[0]

# %%
result = face_recognition.compare_faces(knownEncodings, encode_test)
result
# Out:
# [False, False, False, False, False]

# %%
test = face_recognition.load_image_file('elonmusk_01.jpg')
test = cv2.cvtColor(test, cv2.COLOR_BGR2RGB)
encode_test = face_recognition.face_encodings(test)[0]

result = face_recognition.compare_faces(knownEncodings, encode_test)
result
# Out:
# [False, False, False, False, False]
