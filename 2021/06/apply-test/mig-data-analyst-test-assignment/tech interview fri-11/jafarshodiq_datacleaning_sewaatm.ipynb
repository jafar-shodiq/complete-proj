# %%
import numpy as np
import pandas as pd
from openpyxl import load_workbook
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_excel('data-set.xlsx', sheet_name='SEWAATM', usecols='A:H', header=6)

# %%
df = data.iloc[0:1247]

# %% [markdown]
# Kolom `Tagihan` tidak dimasukkan karena terlalu abstrak. Jika diberikan waktu lebih, akan dapat tercover. Untuk saat ini, hanya sampai kolom `H` saja.

# %%
df.index += 1

# %%
df.drop('Unnamed: 0', axis=1, inplace=True)

# %% [markdown]
# Nama kolom dan semua value yang ada di dalamnya akan dibuat menjadi huruf kecil (lower()) untuk alasan kesetaraan.

# %%
col_dict = {'Unnamed: 1':'tanggal_request',
            'Unnamed: 2':'nama_lokasi',
            'Unnamed: 3':'kota',
            'Unnamed: 4':'masa_sewa_(tahun)',
            'Unnamed: 5':'delivery',
            'Unnamed: 6':'tipe',
            'Unnamed: 7':'jatuh_tempo'}

# %%
df.rename(columns=col_dict, inplace=True)

# %%
df['nama_lokasi'] = df['nama_lokasi'].str.lower()
df['kota'] = df['kota'].str.lower()

# %%
df.head()
# Out:
#        tanggal_request          nama_lokasi              kota  \
# 1  2010-09-21 00:00:00             pln kota    jkt-hub ii rpc
# 2  2010-09-21 00:00:00             perumnas     jkt-hub i rpc
# 3  2010-09-21 00:00:00        tip top depok  jkt-hub viii rpc
# 4  2010-09-21 00:00:00    tip top pdk bambu    jkt-hub vi rpc
# 5  2010-09-21 00:00:00  tip top rawamangun        jkt-hub vii
#
#   masa_sewa_(tahun)             delivery     tipe          jatuh_tempo
# 1               NaN  2010-10-07 00:00:00      522  2013-10-01 00:00:00
# 2               NaN  2010-10-07 00:00:00      522  2013-10-01 00:00:00
# 3               NaN  2010-10-07 00:00:00      522  2013-10-01 00:00:00
# 4               NaN  2010-10-07 00:00:00      522  2013-10-01 00:00:00
# 5               NaN  2010-10-07 00:00:00  529EPP7  2013-10-01 00:00:00

# %%
df.shape
# Out:
# (1247, 7)

# %%
df.isna().sum()
# Out:
# tanggal_request       75
# nama_lokasi            0
# kota                   0
# masa_sewa_(tahun)    826
# delivery             162
# tipe                 106
# jatuh_tempo          175
# dtype: int64

# %% [markdown]
# `masa_sewa_(tahun)` terlalu banyak missing value, kolom ini tidak akan dipakai. Nilai missing value yang lain akan di-drop row-nya.

# %%
df.drop('masa_sewa_(tahun)', axis=1, inplace=True)

# %%
df.dropna(inplace=True)

# %%
df.isna().sum()
# Out:
# tanggal_request    0
# nama_lokasi        0
# kota               0
# delivery           0
# tipe               0
# jatuh_tempo        0
# dtype: int64

# %%
df.shape
# Out:
# (988, 6)

# %% [markdown]
# Datetime `tanggal_request` dan `jatuh_tempo`

# %%
df['tanggal_request'] = df['tanggal_request'].astype(str).str[:10]
df['jatuh_tempo'] = df['jatuh_tempo'].astype(str).str[:10]
df['delivery'] = df['delivery'].astype(str).str[:10]

# %%
# df['tanggal_request'] = df['tanggal_request'].replace('nan', np.nan)
# df['jatuh_tempo'] = df['jatuh_tempo'].replace('nan', np.nan)
# df['delivery'] = df['delivery'].replace('nan', np.nan)

# %%
df
# Out:
#      tanggal_request          nama_lokasi              kota    delivery  \
# 1         2010-09-21             pln kota    jkt-hub ii rpc  2010-10-07
# 2         2010-09-21             perumnas     jkt-hub i rpc  2010-10-07
# 3         2010-09-21        tip top depok  jkt-hub viii rpc  2010-10-07
# 4         2010-09-21    tip top pdk bambu    jkt-hub vi rpc  2010-10-07
# 5         2010-09-21  tip top rawamangun        jkt-hub vii  2010-10-07
# ...              ...                  ...               ...         ...
# 1195      2020-04-24             kk tuban          surabaya  2020-11-18
# 1196      2020-04-24           kk sampang          surabaya  2020-11-18
# 1198      2020-06-11     kk praya mataram           mataram  2020-09-10
# 1206      2020-07-16           kk jombang          sidoarjo  2020-11-18
# 1212      2020-05-05   giant extra serang           cilegon  2020-09-04
#
#          tipe jatuh_tempo
# 1         522  2013-10-01
# 2         522  2013-10-01
# 3         522  2013-10-01
# 4         522  2013-10-01
# 5     529EPP7  2013-10-01
# ...       ...         ...
# 1195   GRGW10  2024-12-01
# 1196   GRGW10  2024-12-01
# 1198   GRGW10  2024-10-01
# 1206   GRGW10  2024-12-01
# 1212   GRGW10  2024-09-01
#
# [988 rows x 6 columns]

# %% [markdown]
# **`status`**

# %%
df[df['kota'].str.contains('rpc')]
# Out:
#     tanggal_request                                        nama_lokasi  \
# 1        2010-09-21                                           pln kota
# 2        2010-09-21                                           perumnas
# 3        2010-09-21                                      tip top depok
# 4        2010-09-21                                  tip top pdk bambu
# 6        2010-09-21                                        lia pramuka
# ..              ...                                                ...
# 280      2013-09-30                     rsup sanglah / stikom denpasar
# 288      2013-10-28                                   spbu adi sucipto
# 290      2013-11-06                                capem harapan indah
# 737      2016-07-25  atm indomaret sudirman simp pangeran hidayat (...
# 868      2012-11-23                          cabang sukabumi (replace)
#
#                  kota    delivery       tipe jatuh_tempo
# 1      jkt-hub ii rpc  2010-10-07        522  2013-10-01
# 2       jkt-hub i rpc  2010-10-07        522  2013-10-01
# 3    jkt-hub viii rpc  2010-10-07        522  2013-10-01
# 4      jkt-hub vi rpc  2010-10-07        522  2013-10-01
# 6       jkt-hub i rpc  2010-10-07        522  2013-10-01
# ..                ...         ...        ...         ...
# 280      denpasar rpc  2013-11-27        WIN  2017-01-01
# 288    yogyakarta rpc  2013-11-27        WIN  2016-12-01
# 290   jkt-hub vii rpc  2013-12-02        WIN  2017-01-01
# 737     pekanbaru rpc  2016-09-05  529EPP7CL  2019-10-01
# 868      sukabumi rpc  2018-03-08  529EPP5W7  2021-03-01
#
# [156 rows x 6 columns]

# %%
df['status'] = ''

# %%
df['status'][df['kota'].str.contains('rpc')] = 'rpc'
df['status'][df['kota'].str.contains('cancel')] = 'cancel'
df['status'][df['kota'].str.contains('off')] = 'off'

df['status'] = df['status'].replace('', '[status]')

# %%
df
# Out:
#      tanggal_request          nama_lokasi              kota    delivery  \
# 1         2010-09-21             pln kota    jkt-hub ii rpc  2010-10-07
# 2         2010-09-21             perumnas     jkt-hub i rpc  2010-10-07
# 3         2010-09-21        tip top depok  jkt-hub viii rpc  2010-10-07
# 4         2010-09-21    tip top pdk bambu    jkt-hub vi rpc  2010-10-07
# 5         2010-09-21  tip top rawamangun        jkt-hub vii  2010-10-07
# ...              ...                  ...               ...         ...
# 1195      2020-04-24             kk tuban          surabaya  2020-11-18
# 1196      2020-04-24           kk sampang          surabaya  2020-11-18
# 1198      2020-06-11     kk praya mataram           mataram  2020-09-10
# 1206      2020-07-16           kk jombang          sidoarjo  2020-11-18
# 1212      2020-05-05   giant extra serang           cilegon  2020-09-04
#
#          tipe jatuh_tempo    status
# 1         522  2013-10-01       rpc
# 2         522  2013-10-01       rpc
# 3         522  2013-10-01       rpc
# 4         522  2013-10-01       rpc
# 5     529EPP7  2013-10-01  [status]
# ...       ...         ...       ...
# 1195   GRGW10  2024-12-01  [status]
# 1196   GRGW10  2024-12-01  [status]
# 1198   GRGW10  2024-10-01  [status]
# 1206   GRGW10  2024-12-01  [status]
# 1212   GRGW10  2024-09-01  [status]
#
# [988 rows x 7 columns]

# %%
df['request_tgl'] = df['tanggal_request'].str[-2:]
df['request_bln'] = df['tanggal_request'].str[5:7]
df['request_thn'] = df['tanggal_request'].str[:4]

df['request_tgl'] = df['request_tgl'][~df['request_tgl'].str.contains('-')]
df['request_bln'] = df['request_bln'][~df['request_bln'].str.contains('-')]
df['request_thn'] = df['request_thn'][~df['request_thn'].str.contains('-')]

df.dropna(inplace=True)

df['request_tgl'] = df['request_tgl'].astype(int)
df['request_bln'] = df['request_bln'].astype(int)
df['request_thn'] = df['request_thn'].astype(int)

# %%
df['delivery_tgl'] = df['delivery'].str[-2:]
df['delivery_bln'] = df['delivery'].str[5:7]
df['delivery_thn'] = df['delivery'].str[:4]

df['delivery_tgl'] = df['delivery_tgl'][~df['delivery_tgl'].str.contains('-')]
df['delivery_bln'] = df['delivery_bln'][~df['delivery_bln'].str.contains('-')]
df['delivery_thn'] = df['delivery_thn'][~df['delivery_thn'].str.contains('-')]

df.dropna(inplace=True)

df['delivery_tgl'] = df['delivery_tgl'].astype(int)
df['delivery_bln'] = df['delivery_bln'].astype(int)
df['delivery_thn'] = df['delivery_thn'].astype(int)

# %%
df['jtempo_tgl'] = df['jatuh_tempo'].str[-2:]
df['jtempo_bln'] = df['jatuh_tempo'].str[5:7]
df['jtempo_thn'] = df['jatuh_tempo'].str[:4]

df['jtempo_tgl'] = df['jtempo_tgl'][~df['jtempo_tgl'].str.contains('-')]
df['jtempo_bln'] = df['jtempo_bln'][~df['jtempo_bln'].str.contains('-')]
df['jtempo_thn'] = df['jtempo_thn'][~df['jtempo_thn'].str.contains('-')]

df.dropna(inplace=True)

df['jtempo_tgl'] = df['jtempo_tgl'].astype(int)
df['jtempo_bln'] = df['jtempo_bln'].astype(int)
df['jtempo_thn'] = df['jtempo_thn'].astype(int)

# %%
df
# Out:
#      tanggal_request          nama_lokasi              kota    delivery  \
# 1         2010-09-21             pln kota    jkt-hub ii rpc  2010-10-07
# 2         2010-09-21             perumnas     jkt-hub i rpc  2010-10-07
# 3         2010-09-21        tip top depok  jkt-hub viii rpc  2010-10-07
# 4         2010-09-21    tip top pdk bambu    jkt-hub vi rpc  2010-10-07
# 5         2010-09-21  tip top rawamangun        jkt-hub vii  2010-10-07
# ...              ...                  ...               ...         ...
# 1195      2020-04-24             kk tuban          surabaya  2020-11-18
# 1196      2020-04-24           kk sampang          surabaya  2020-11-18
# 1198      2020-06-11     kk praya mataram           mataram  2020-09-10
# 1206      2020-07-16           kk jombang          sidoarjo  2020-11-18
# 1212      2020-05-05   giant extra serang           cilegon  2020-09-04
#
#          tipe jatuh_tempo    status  request_tgl  request_bln  request_thn  \
# 1         522  2013-10-01       rpc           21            9         2010
# 2         522  2013-10-01       rpc           21            9         2010
# 3         522  2013-10-01       rpc           21            9         2010
# 4         522  2013-10-01       rpc           21            9         2010
# 5     529EPP7  2013-10-01  [status]           21            9         2010
# ...       ...         ...       ...          ...          ...          ...
# 1195   GRGW10  2024-12-01  [status]           24            4         2020
# 1196   GRGW10  2024-12-01  [status]           24            4         2020
# 1198   GRGW10  2024-10-01  [status]           11            6         2020
# 1206   GRGW10  2024-12-01  [status]           16            7         2020
# 1212   GRGW10  2024-09-01  [status]            5            5         2020
#
#       delivery_tgl  delivery_bln  delivery_thn  jtempo_tgl  jtempo_bln  \
# 1                7            10          2010           1          10
# 2                7            10          2010           1          10
# 3                7            10          2010           1          10
# 4                7            10          2010           1          10
# 5                7            10          2010           1          10
# ...            ...           ...           ...         ...         ...
# 1195            18            11          2020           1          12
# 1196            18            11          2020           1          12
# 1198            10             9          2020           1          10
# 1206            18            11          2020           1          12
# 1212             4             9          2020           1           9
#
#       jtempo_thn
# 1           2013
# 2           2013
# 3           2013
# 4           2013
# 5           2013
# ...          ...
# 1195        2024
# 1196        2024
# 1198        2024
# 1206        2024
# 1212        2024
#
# [982 rows x 16 columns]

# %%
df['tipe'] = df['tipe'].astype(str)

# %% [markdown]
# ## Mengemas ke dalam dataframe baru

# %%
df_final = pd.DataFrame()

# %%
df_final['nama_lokasi'] = df['nama_lokasi']
df_final['kota'] = df['kota']
df_final['status'] = df['status']
df_final['tipe'] = df['tipe']
df_final['request_tgl'] = df['request_tgl']
df_final['request_bln'] = df['request_bln']
df_final['request_thn'] = df['request_thn']
df_final['delivery_tgl'] = df['delivery_tgl']
df_final['delivery_bln'] = df['delivery_bln']
df_final['delivery_thn'] = df['delivery_thn']
df_final['jtempo_tgl'] = df['jtempo_tgl']
df_final['jtempo_bln'] = df['jtempo_bln']
df_final['jtempo_thn'] = df['jtempo_thn']

# %%
df_final
# Out:
#               nama_lokasi              kota    status     tipe  request_tgl  \
# 1                pln kota    jkt-hub ii rpc       rpc      522           21
# 2                perumnas     jkt-hub i rpc       rpc      522           21
# 3           tip top depok  jkt-hub viii rpc       rpc      522           21
# 4       tip top pdk bambu    jkt-hub vi rpc       rpc      522           21
# 5     tip top rawamangun        jkt-hub vii  [status]  529EPP7           21
# ...                   ...               ...       ...      ...          ...
# 1195             kk tuban          surabaya  [status]   GRGW10           24
# 1196           kk sampang          surabaya  [status]   GRGW10           24
# 1198     kk praya mataram           mataram  [status]   GRGW10           11
# 1206           kk jombang          sidoarjo  [status]   GRGW10           16
# 1212   giant extra serang           cilegon  [status]   GRGW10            5
#
#       request_bln  request_thn  delivery_tgl  delivery_bln  delivery_thn  \
# 1               9         2010             7            10          2010
# 2               9         2010             7            10          2010
# 3               9         2010             7            10          2010
# 4               9         2010             7            10          2010
# 5               9         2010             7            10          2010
# ...           ...          ...           ...           ...           ...
# 1195            4         2020            18            11          2020
# 1196            4         2020            18            11          2020
# 1198            6         2020            10             9          2020
# 1206            7         2020            18            11          2020
# 1212            5         2020             4             9          2020
#
#       jtempo_tgl  jtempo_bln  jtempo_thn
# 1              1          10        2013
# 2              1          10        2013
# 3              1          10        2013
# 4              1          10        2013
# 5              1          10        2013
# ...          ...         ...         ...
# 1195           1          12        2024
# 1196           1          12        2024
# 1198           1          10        2024
# 1206           1          12        2024
# 1212           1           9        2024
#
# [982 rows x 13 columns]

# %% [markdown]
# Save ke excel

# %%
book = load_workbook('data-cleaned.xlsx')
writer = pd.ExcelWriter('data-cleaned.xlsx', engine = 'openpyxl')
writer.book = book

# %%
df_final.to_excel(writer, sheet_name='sewa_atm')
writer.save()
writer.close()

# %% [markdown]
# Load kembali

# %%
load_data = pd.read_excel('data-cleaned.xlsx', sheet_name='sewa_atm', index_col=0)
load_data
# Out:
#               nama_lokasi              kota    status     tipe  request_tgl  \
# 1                pln kota    jkt-hub ii rpc       rpc      522           21
# 2                perumnas     jkt-hub i rpc       rpc      522           21
# 3           tip top depok  jkt-hub viii rpc       rpc      522           21
# 4       tip top pdk bambu    jkt-hub vi rpc       rpc      522           21
# 5     tip top rawamangun        jkt-hub vii  [status]  529EPP7           21
# ...                   ...               ...       ...      ...          ...
# 1195             kk tuban          surabaya  [status]   GRGW10           24
# 1196           kk sampang          surabaya  [status]   GRGW10           24
# 1198     kk praya mataram           mataram  [status]   GRGW10           11
# 1206           kk jombang          sidoarjo  [status]   GRGW10           16
# 1212   giant extra serang           cilegon  [status]   GRGW10            5
#
#       request_bln  request_thn  delivery_tgl  delivery_bln  delivery_thn  \
# 1               9         2010             7            10          2010
# 2               9         2010             7            10          2010
# 3               9         2010             7            10          2010
# 4               9         2010             7            10          2010
# 5               9         2010             7            10          2010
# ...           ...          ...           ...           ...           ...
# 1195            4         2020            18            11          2020
# 1196            4         2020            18            11          2020
# 1198            6         2020            10             9          2020
# 1206            7         2020            18            11          2020
# 1212            5         2020             4             9          2020
#
#       jtempo_tgl  jtempo_bln  jtempo_thn
# 1              1          10        2013
# 2              1          10        2013
# 3              1          10        2013
# 4              1          10        2013
# 5              1          10        2013
# ...          ...         ...         ...
# 1195           1          12        2024
# 1196           1          12        2024
# 1198           1          10        2024
# 1206           1          12        2024
# 1212           1           9        2024
#
# [982 rows x 13 columns]
