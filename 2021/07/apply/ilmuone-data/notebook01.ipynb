# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import glob
import re
import warnings
warnings.filterwarnings('ignore')

# %%
y10_q1 = pd.read_csv('dataset/2020Q1.csv')
y10_q1
# Out:
#             Date      Category1     Category2 Category3      Maker   Sales  \
# 0     2020-01-02  Refrigerators           NaN       NaN     Funami   968.0
# 1     2020-01-02          Ovens             &  Cooktops      Ikeda   300.0
# 2     2020-01-02        Washers             &    Dryers    Okamoto   575.0
# 3     2020-01-02            Air  Conditioners       NaN      Akaza  2125.0
# 4     2020-01-02            Air  Conditioners       NaN    Toshino     NaN
# ...          ...            ...           ...       ...        ...     ...
# 3220  2020-03-31          Water       Heaters       NaN      Ikeda   226.0
# 3221  2020-03-31           Rice       Cookers       NaN  Matsumoto  4934.0
# 3222  2020-03-31           Rice       Cookers       NaN      Akaza  1847.0
# 3223  2020-03-31          Ovens             &  Cooktops    Sugiura     NaN
# 3224  2020-03-31        Washers             &    Dryers    Shimada   404.0
#
#       Identifier
# 0      BIBIOOIHA
# 1     ZTEIJGNYNC
# 2     FUFHZH9WRW
# 3     IVOI4I03JA
# 4     RVFWTWSMNU
# ...          ...
# 3220  AHSRVKIOLJ
# 3221  TJLYGOSEBQ
# 3222  KSNN8R2CCO
# 3223  LBABGBBMJJ
# 3224  RBRMDIXXGL
#
# [3225 rows x 7 columns]

# %%
y10_q2 = pd.read_csv('dataset/2010Q2.csv')
y10_q2
# Out:
#             Date      Category1 Category2 Category3      Maker   Sales  \
# 0     2010-04-01    Dishwashers       NaN       NaN     Nanase  4708.0
# 1     2010-04-01           Rice   Cookers       NaN      Ikeda   279.0
# 2     2010-04-01         Vacuum  Cleaners       NaN  Hayashida   149.0
# 3     2010-04-01          Water   Heaters       NaN   Furutani   614.0
# 4     2010-04-01  Refrigerators       NaN       NaN      Akaza  1122.0
# ...          ...            ...       ...       ...        ...     ...
# 2723  2010-06-30         Vacuum  Cleaners       NaN     Hisami   666.0
# 2724  2010-06-30          Water     Pumps       NaN  Yoshikawa  2171.0
# 2725  2010-06-30          Ovens         &  Cooktops      Akaza   566.0
# 2726  2010-06-30          Water     Pumps       NaN   Furutani  8749.0
# 2727  2010-06-30    Dishwashers       NaN       NaN   Katayama  1458.0
#
#       Identifier
# 0     AVXSMNNRDX
# 1     JYINACMKHE
# 2     GCPKFKSEWG
# 3     PF4KB33DVZ
# 4     XVIOZZOUTN
# ...          ...
# 2723  VNZSEQOSNP
# 2724  TLSY3MWMK8
# 2725  PHFB77Q5OA
# 2726  FVDHIZGQRC
# 2727  ZWNGQMERMH
#
# [2728 rows x 7 columns]

# %%
y10_q3 = pd.read_csv('dataset/2010Q3.csv')
y10_q3
# Out:
#             Date    Category1     Category2 Category3      Maker    Sales  \
# 0     2010-07-01          Air  Conditioners       NaN     Funami    909.0
# 1     2010-07-01        Water         Pumps       NaN   Furutani   8799.0
# 2     2010-07-01  Televisions           NaN       NaN    Okamoto    407.0
# 3     2010-07-01         Rice       Cookers       NaN  Matsumoto    661.0
# 4     2010-07-01       Vacuum      Cleaners       NaN    Toshino    377.0
# ...          ...          ...           ...       ...        ...      ...
# 2635  2010-09-30        Water         Pumps       NaN     Funami  18409.0
# 2636  2010-09-30        Ovens             &  Cooktops    Shimada   2020.0
# 2637  2010-09-30      Washers             &    Dryers    Shimada   4672.0
# 2638  2010-09-30      Washers             &    Dryers    Okamoto   1974.0
# 2639  2010-09-30          Air  Conditioners       NaN     Funami   1006.0
#
#       Identifier
# 0     HWQKLKDVSB
# 1     FVDHIZGQRC
# 2     HANYALJGGA
# 3     TJLYGOSEBQ
# 4     NHXJMH55UY
# ...          ...
# 2635  ZJPMAJIMIT
# 2636  WVJTPVZKAQ
# 2637  RBRMDIXXGL
# 2638  FUFHZH9WRW
# 2639  HWQKLKDVSB
#
# [2640 rows x 7 columns]

# %%
y21_q2 = pd.read_csv('dataset/2021Q2.csv')
y21_q2
# Out:
#             Date      Category1     Category2 Category3      Maker    Sales  \
# 0     2021-04-01          Water       Heaters       NaN    Sugiura   1538.0
# 1     2021-04-01            Air  Conditioners       NaN  Yoshikawa   5691.0
# 2     2021-04-01  Refrigerators           NaN       NaN      Omuro  31135.0
# 3     2021-04-01         Vacuum      Cleaners       NaN     Funami    927.0
# 4     2021-04-01        Washers             &    Dryers      Akaza   5343.0
# ...          ...            ...           ...       ...        ...      ...
# 1035  2021-04-29            Air  Conditioners       NaN      Akaza   1609.0
# 1036  2021-04-29        Washers             &    Dryers      Akaza   5422.0
# 1037  2021-04-29         Vacuum      Cleaners       NaN  Hayashida    539.0
# 1038  2021-04-29          Water         Pumps       NaN   Furutani  10547.0
# 1039  2021-04-29    Televisions           NaN       NaN     Kikuma    805.0
#
#       Identifier
# 0     UPJKNMIDRB
# 1     NTMMOBBPEE
# 2     FUWHINIXUA
# 3     VEWPPXWTWS
# 4     VUQUQMHODG
# ...          ...
# 1035  IVOI4I03JA
# 1036  VUQUQMHODG
# 1037  GCPKFKSEWG
# 1038  FVDHIZGQRC
# 1039  FRBLLORNXN
#
# [1040 rows x 7 columns]

# %%
# 2010
y10_q1 = pd.read_csv('dataset/2010Q1.csv')
y10_q2 = pd.read_csv('dataset/2010Q2.csv')
y10_q3 = pd.read_csv('dataset/2010Q3.csv')
y10_q4 = pd.read_csv('dataset/2010Q4.csv')

# 2011
y11_q1 = pd.read_csv('dataset/2011Q1.csv')
y11_q2 = pd.read_csv('dataset/2011Q2.csv')
y11_q3 = pd.read_csv('dataset/2011Q3.csv')
y11_q4 = pd.read_csv('dataset/2011Q4.csv')

# 2012

# %%
path = 'D:/complete-proj/2021/07/apply/ilmuone-data/dataset-2'
all_files = glob.glob(path + '/*.csv')

# %%
lst = []
for filename in all_files:
    df = pd.read_csv(filename, index_col=None, header=0)
    lst.append(df)

# %%
frame = pd.concat(lst, axis=0, ignore_index=True)

# %%
frame
# Out:
#              Date      Category1     Category2 Category3      Maker   Sales  \
# 0      2010-07-01            Air  Conditioners       NaN     Funami   909.0
# 1      2010-07-01          Water         Pumps       NaN   Furutani  8799.0
# 2      2010-07-01    Televisions           NaN       NaN    Okamoto   407.0
# 3      2010-07-01           Rice       Cookers       NaN  Matsumoto   661.0
# 4      2010-07-01         Vacuum      Cleaners       NaN    Toshino   377.0
# ...           ...            ...           ...       ...        ...     ...
# 13632  2011-09-30  Refrigerators           NaN       NaN  Yoshikawa  4594.0
# 13633  2011-09-30    Televisions           NaN       NaN    Shimada     NaN
# 13634  2011-09-30           Rice       Cookers       NaN  Matsumoto  2405.0
# 13635  2011-09-30  Refrigerators           NaN       NaN     Nanase   513.0
# 13636  2011-09-30         Vacuum      Cleaners       NaN      Akaza   500.0
#
#        Identifier
# 0      HWQKLKDVSB
# 1      FVDHIZGQRC
# 2      HANYALJGGA
# 3      TJLYGOSEBQ
# 4      NHXJMH55UY
# ...           ...
# 13632  UG2IU3EFWI
# 13633  GHOAPVUVYL
# 13634  TJLYGOSEBQ
# 13635  GQUIAFQIRH
# 13636  ZBYVQNRPUP
#
# [13637 rows x 7 columns]

# %%
frame['Date'] = pd.to_datetime(frame['Date'])

# %%
frame['Date'].dt.year.value_counts()
# Out:
# 2011    8235
# 2010    5402
# Name: Date, dtype: int64

# %%
path = 'D:/complete-proj/2021/07/apply/ilmuone-data/dataset'
all_files = glob.glob(path + '/*.csv')

# %%
lst = []
for filename in all_files:
    data = pd.read_csv(filename, index_col=None, header=0)
    lst.append(data)

# %%
df = pd.concat(lst, axis=0, ignore_index=True)

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 134964 entries, 0 to 134963
# Data columns (total 7 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   Date        134964 non-null  datetime64[ns]
#  1   Category1   134964 non-null  object
#  2   Category2   93196 non-null   object
#  3   Category3   30603 non-null   object
#  4   Maker       134964 non-null  object
#  5   Sales       129588 non-null  float64
#  6   Identifier  134964 non-null  object
# dtypes: datetime64[ns](1), float64(1), object(5)
# memory usage: 7.2+ MB

# %%
df.isnull().sum()
# Out:
# Date               0
# Category1          0
# Category2      41768
# Category3     104361
# Maker              0
# Sales           5376
# Identifier         0
# dtype: int64

# %%
y10_q1
# Out:
#             Date      Category1     Category2 Category3     Maker    Sales  \
# 0     2010-02-15            Air  Conditioners       NaN   Toshino   2143.0
# 1     2010-02-15          Water       Heaters       NaN  Furutani    567.0
# 2     2010-02-15        Washers             &    Dryers     Akaza   3515.0
# 3     2010-02-15  Refrigerators           NaN       NaN     Akaza    687.0
# 4     2010-02-15        Washers             &    Dryers   Shimada    435.0
# ...          ...            ...           ...       ...       ...      ...
# 1359  2010-03-31          Ovens             &  Cooktops   Sugiura   4257.0
# 1360  2010-03-31          Ovens             &  Cooktops   Toshino   3483.0
# 1361  2010-03-31            Air  Conditioners       NaN   Toshino   2606.0
# 1362  2010-03-31         Vacuum      Cleaners       NaN   Toshino    450.0
# 1363  2010-03-31          Water         Pumps       NaN    Funami  14243.0
#
#       Identifier
# 0     RVFWTWSMNU
# 1     PF4KB33DVZ
# 2     VUQUQMHODG
# 3     XVIOZZOUTN
# 4     RBRMDIXXGL
# ...          ...
# 1359  LBABGBBMJJ
# 1360  LFIEXBAPFQ
# 1361  RVFWTWSMNU
# 1362  NHXJMH55UY
# 1363  ZJPMAJIMIT
#
# [1364 rows x 7 columns]

# %%
y10_q1['Category'] = y10_q1['Category1'] + ' ' + y10_q1['Category2']

# %%
y10_q1['Category']
# Out:
# 0       Air Conditioners
# 1          Water Heaters
# 2              Washers &
# 3                    NaN
# 4              Washers &
#               ...
# 1359             Ovens &
# 1360             Ovens &
# 1361    Air Conditioners
# 1362     Vacuum Cleaners
# 1363         Water Pumps
# Name: Category, Length: 1364, dtype: object

# %%
df2 = y10_q2.copy()

# %%
df2
# Out:
#             Date      Category1 Category2 Category3      Maker   Sales  \
# 0     2010-04-01    Dishwashers       NaN       NaN     Nanase  4708.0
# 1     2010-04-01           Rice   Cookers       NaN      Ikeda   279.0
# 2     2010-04-01         Vacuum  Cleaners       NaN  Hayashida   149.0
# 3     2010-04-01          Water   Heaters       NaN   Furutani   614.0
# 4     2010-04-01  Refrigerators       NaN       NaN      Akaza  1122.0
# ...          ...            ...       ...       ...        ...     ...
# 2723  2010-06-30         Vacuum  Cleaners       NaN     Hisami   666.0
# 2724  2010-06-30          Water     Pumps       NaN  Yoshikawa  2171.0
# 2725  2010-06-30          Ovens         &  Cooktops      Akaza   566.0
# 2726  2010-06-30          Water     Pumps       NaN   Furutani  8749.0
# 2727  2010-06-30    Dishwashers       NaN       NaN   Katayama  1458.0
#
#       Identifier
# 0     AVXSMNNRDX
# 1     JYINACMKHE
# 2     GCPKFKSEWG
# 3     PF4KB33DVZ
# 4     XVIOZZOUTN
# ...          ...
# 2723  VNZSEQOSNP
# 2724  TLSY3MWMK8
# 2725  PHFB77Q5OA
# 2726  FVDHIZGQRC
# 2727  ZWNGQMERMH
#
# [2728 rows x 7 columns]

# %%
df2['Category2'].value_counts(dropna=False)
# Out:
# NaN             806
# &               682
# Cookers         372
# Cleaners        310
# Conditioners    248
# Pumps           186
# Heaters         124
# Name: Category2, dtype: int64

# %%
df2['Category2'].fillna('').value_counts()
# Out:
#                 806
# &               682
# Cookers         372
# Cleaners        310
# Conditioners    248
# Pumps           186
# Heaters         124
# Name: Category2, dtype: int64

# %%
df
# Out:
#              Date      Category1     Category2 Category3      Maker    Sales  \
# 0      2010-02-15            Air  Conditioners       NaN    Toshino   2143.0
# 1      2010-02-15          Water       Heaters       NaN   Furutani    567.0
# 2      2010-02-15        Washers             &    Dryers      Akaza   3515.0
# 3      2010-02-15  Refrigerators           NaN       NaN      Akaza    687.0
# 4      2010-02-15        Washers             &    Dryers    Shimada    435.0
# ...           ...            ...           ...       ...        ...      ...
# 134959 2021-04-29            Air  Conditioners       NaN      Akaza   1609.0
# 134960 2021-04-29        Washers             &    Dryers      Akaza   5422.0
# 134961 2021-04-29         Vacuum      Cleaners       NaN  Hayashida    539.0
# 134962 2021-04-29          Water         Pumps       NaN   Furutani  10547.0
# 134963 2021-04-29    Televisions           NaN       NaN     Kikuma    805.0
#
#         Identifier
# 0       RVFWTWSMNU
# 1       PF4KB33DVZ
# 2       VUQUQMHODG
# 3       XVIOZZOUTN
# 4       RBRMDIXXGL
# ...            ...
# 134959  IVOI4I03JA
# 134960  VUQUQMHODG
# 134961  GCPKFKSEWG
# 134962  FVDHIZGQRC
# 134963  FRBLLORNXN
#
# [134964 rows x 7 columns]

# %%
df['Category1'].value_counts(dropna=False)
# Out:
# Water            20859
# Refrigerators    19476
# Rice             16695
# Ovens            16693
# Vacuum           13911
# Washers          13910
# Dishwashers      11843
# Air              11128
# Televisions      10449
# Name: Category1, dtype: int64

# %%
df['Category2'].value_counts(dropna=False)
# Out:
# NaN             41768
# &               30603
# Cookers         16695
# Cleaners        13911
# Conditioners    11128
# Heaters         10567
# Pumps           10292
# Name: Category2, dtype: int64

# %%
df['Category'] = df['Category1'] + df['Category2']

# %%
# df['Category'] = ''

# %%
df
# Out:
#              Date      Category1     Category2 Category3      Maker    Sales  \
# 0      2010-02-15            Air  Conditioners       NaN    Toshino   2143.0
# 1      2010-02-15          Water       Heaters       NaN   Furutani    567.0
# 2      2010-02-15        Washers             &    Dryers      Akaza   3515.0
# 3      2010-02-15  Refrigerators           NaN       NaN      Akaza    687.0
# 4      2010-02-15        Washers             &    Dryers    Shimada    435.0
# ...           ...            ...           ...       ...        ...      ...
# 134959 2021-04-29            Air  Conditioners       NaN      Akaza   1609.0
# 134960 2021-04-29        Washers             &    Dryers      Akaza   5422.0
# 134961 2021-04-29         Vacuum      Cleaners       NaN  Hayashida    539.0
# 134962 2021-04-29          Water         Pumps       NaN   Furutani  10547.0
# 134963 2021-04-29    Televisions           NaN       NaN     Kikuma    805.0
#
#         Identifier Category
# 0       RVFWTWSMNU
# 1       PF4KB33DVZ
# 2       VUQUQMHODG
# 3       XVIOZZOUTN
# 4       RBRMDIXXGL
# ...            ...      ...
# 134959  IVOI4I03JA
# 134960  VUQUQMHODG
# 134961  GCPKFKSEWG
# 134962  FVDHIZGQRC
# 134963  FRBLLORNXN
#
# [134964 rows x 8 columns]

# %%
df['Category2'] = df['Category2'].fillna('')
df['Category3'] = df['Category3'].fillna('')

# %%
df['Category'] = df['Category1'] + ' ' + df['Category2'] + ' ' + df['Category3']

# %%
df
# Out:
#              Date      Category1     Category2 Category3      Maker    Sales  \
# 0      2010-02-15            Air  Conditioners              Toshino   2143.0
# 1      2010-02-15          Water       Heaters             Furutani    567.0
# 2      2010-02-15        Washers             &    Dryers      Akaza   3515.0
# 3      2010-02-15  Refrigerators                              Akaza    687.0
# 4      2010-02-15        Washers             &    Dryers    Shimada    435.0
# ...           ...            ...           ...       ...        ...      ...
# 134959 2021-04-29            Air  Conditioners                Akaza   1609.0
# 134960 2021-04-29        Washers             &    Dryers      Akaza   5422.0
# 134961 2021-04-29         Vacuum      Cleaners            Hayashida    539.0
# 134962 2021-04-29          Water         Pumps             Furutani  10547.0
# 134963 2021-04-29    Televisions                             Kikuma    805.0
#
#         Identifier           Category
# 0       RVFWTWSMNU  Air Conditioners
# 1       PF4KB33DVZ     Water Heaters
# 2       VUQUQMHODG   Washers & Dryers
# 3       XVIOZZOUTN    Refrigerators
# 4       RBRMDIXXGL   Washers & Dryers
# ...            ...                ...
# 134959  IVOI4I03JA  Air Conditioners
# 134960  VUQUQMHODG   Washers & Dryers
# 134961  GCPKFKSEWG   Vacuum Cleaners
# 134962  FVDHIZGQRC       Water Pumps
# 134963  FRBLLORNXN      Televisions
#
# [134964 rows x 8 columns]

# %%
df['Category'].value_counts()
# Out:
# Refrigerators        19476
# Rice Cookers         16695
# Ovens & Cooktops     16693
# Vacuum Cleaners      13911
# Washers & Dryers     13910
# Dishwashers          11843
# Air Conditioners     11128
# Water Heaters        10567
# Televisions          10449
# Water Pumps          10292
# Name: Category, dtype: int64

# %%
df['Maker'].value_counts()
# Out:
# Akaza        16694
# Funami       13911
# Toshino      11129
# Shimada      11129
# Ikeda        10162
# Yoshikawa     9513
# Furutani      8347
# Sugiura       8346
# Omuro         7645
# Nanase        5836
# Okamoto       5565
# Hayashida     5564
# Hisami        5564
# Katayama      5564
# Matsumoto     5383
# Kikuma        4612
# Name: Maker, dtype: int64

# %%
df['Identifier'][df['Identifier'].str.contains(r'[0-9]')]
# Out:
# 1         PF4KB33DVZ
# 5         FUFHZH9WRW
# 7         QFY2WV5LUE
# 8         AHJK2FTTBH
# 9         UG2IU3EFWI
#              ...
# 134952    UG2IU3EFWI
# 134953    AHJK2FTTBH
# 134957    MXC7NMNBIW
# 134958    PHFB77Q5OA
# 134959    IVOI4I03JA
# Name: Identifier, Length: 41793, dtype: object

# %%
df['Identifier'][df['Identifier'].str.contains(r'[0-9]')].count()
# Out:
# 41793

# %%
df['Identifier'][~df['Identifier'].str.contains(r'[0-9]')]
# Out:
# 0         RVFWTWSMNU
# 2         VUQUQMHODG
# 3         XVIOZZOUTN
# 4         RBRMDIXXGL
# 6          BIBIOOIHA
#              ...
# 134956    WVJTPVZKAQ
# 134960    VUQUQMHODG
# 134961    GCPKFKSEWG
# 134962    FVDHIZGQRC
# 134963    FRBLLORNXN
# Name: Identifier, Length: 93171, dtype: object

# %%
df['Identifier'][~df['Identifier'].str.contains(r'[0-9]')].count()
# Out:
# 93171

# %%
df = df[~df['Identifier'].str.contains(r'[0-9]')]

# %%
df = df.drop(['Category1', 'Category2', 'Category3'], axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 93171 entries, 0 to 134963
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Date        93171 non-null  datetime64[ns]
#  1   Maker       93171 non-null  object
#  2   Sales       89498 non-null  float64
#  3   Identifier  93171 non-null  object
#  4   Category    93171 non-null  object
# dtypes: datetime64[ns](1), float64(1), object(3)
# memory usage: 4.3+ MB

# %%
df
# Out:
#              Date      Maker    Sales  Identifier           Category
# 0      2010-02-15    Toshino   2143.0  RVFWTWSMNU  Air Conditioners
# 2      2010-02-15      Akaza   3515.0  VUQUQMHODG   Washers & Dryers
# 3      2010-02-15      Akaza    687.0  XVIOZZOUTN    Refrigerators
# 4      2010-02-15    Shimada    435.0  RBRMDIXXGL   Washers & Dryers
# 6      2010-02-15     Funami    726.0   BIBIOOIHA    Refrigerators
# ...           ...        ...      ...         ...                ...
# 134956 2021-04-29    Shimada   1258.0  WVJTPVZKAQ   Ovens & Cooktops
# 134960 2021-04-29      Akaza   5422.0  VUQUQMHODG   Washers & Dryers
# 134961 2021-04-29  Hayashida    539.0  GCPKFKSEWG   Vacuum Cleaners
# 134962 2021-04-29   Furutani  10547.0  FVDHIZGQRC       Water Pumps
# 134963 2021-04-29     Kikuma    805.0  FRBLLORNXN      Televisions
#
# [93171 rows x 5 columns]

# %%
df.isnull().sum()
# Out:
# Date             0
# Maker            0
# Sales         3673
# Identifier       0
# Category         0
# dtype: int64

# %%
df[df['Sales'].isnull()]
# Out:
#              Date      Maker  Sales  Identifier           Category
# 27     2010-02-15      Omuro    NaN  HWTFIGIXOL   Ovens & Cooktops
# 54     2010-02-16    Sugiura    NaN  UPJKNMIDRB     Water Heaters
# 129    2010-02-17    Toshino    NaN  RVFWTWSMNU  Air Conditioners
# 189    2010-02-19      Akaza    NaN  ZBYVQNRPUP   Vacuum Cleaners
# 224    2010-02-22   Katayama    NaN  ZWNGQMERMH      Dishwashers
# ...           ...        ...    ...         ...                ...
# 134869 2021-04-28     Funami    NaN  VEWPPXWTWS   Vacuum Cleaners
# 134877 2021-04-28      Akaza    NaN  VUQUQMHODG   Washers & Dryers
# 134885 2021-04-28  Yoshikawa    NaN  DUVTZNWNAB     Water Heaters
# 134918 2021-04-29      Akaza    NaN  XVIOZZOUTN    Refrigerators
# 134928 2021-04-29    Shimada    NaN  RBRMDIXXGL   Washers & Dryers
#
# [3673 rows x 5 columns]

# %%
df['Maker'][df['Sales'].isnull()].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df.groupby(by='Category').mean().round(2)
# Out:
#                       Sales
# Category
# Air Conditioners    4212.47
# Dishwashers         1640.59
# Ovens & Cooktops    6453.09
# Refrigerators       4814.69
# Rice Cookers        4594.25
# Televisions         1202.69
# Vacuum Cleaners      943.59
# Washers & Dryers    4944.57
# Water Heaters       1239.01
# Water Pumps        14921.47

# %%
df['Category'][df['Sales'].isnull()].value_counts()
# Out:
# Ovens & Cooktops     556
# Rice Cookers         449
# Vacuum Cleaners      444
# Refrigerators        430
# Televisions          400
# Air Conditioners     365
# Dishwashers          296
# Water Heaters        295
# Washers & Dryers     236
# Water Pumps          202
# Name: Category, dtype: int64

# %%
df[df['Identifier'] == 'HWTFIGIXOL']
# Out:
#              Date  Maker    Sales  Identifier          Category
# 27     2010-02-15  Omuro      NaN  HWTFIGIXOL  Ovens & Cooktops
# 69     2010-02-16  Omuro  31022.0  HWTFIGIXOL  Ovens & Cooktops
# 130    2010-02-17  Omuro  31465.0  HWTFIGIXOL  Ovens & Cooktops
# 141    2010-02-18  Omuro  30602.0  HWTFIGIXOL  Ovens & Cooktops
# 188    2010-02-19  Omuro  30008.0  HWTFIGIXOL  Ovens & Cooktops
# ...           ...    ...      ...         ...               ...
# 134714 2021-04-23  Omuro  12059.0  HWTFIGIXOL  Ovens & Cooktops
# 134796 2021-04-26  Omuro  11870.0  HWTFIGIXOL  Ovens & Cooktops
# 134812 2021-04-27  Omuro  11751.0  HWTFIGIXOL  Ovens & Cooktops
# 134865 2021-04-28  Omuro  11921.0  HWTFIGIXOL  Ovens & Cooktops
# 134916 2021-04-29  Omuro  11995.0  HWTFIGIXOL  Ovens & Cooktops
#
# [2782 rows x 5 columns]

# %%
df['Identifier'].value_counts()
# Out:
# JYINACMKHE    2783
# HANYALJGGA    2783
# FUWHINIXUA    2783
# ZJPMAJIMIT    2783
# ZJZZJNDFOZ    2783
# RVFWTWSMNU    2782
# AVXSMNNRDX    2782
# LBABGBBMJJ    2782
# WVJTPVZKAQ    2782
# ZTEIJGNYNC    2782
# GQUIAFQIRH    2782
# ZWNGQMERMH    2782
# FVDHIZGQRC    2782
# ECQPIOYXZO    2782
# VZAQLWEGXU    2782
# TJLYGOSEBQ    2782
# VUQUQMHODG    2782
# HWTFIGIXOL    2782
# LFIEXBAPFQ    2782
# VNZSEQOSNP    2782
# XVIOZZOUTN    2782
# RBRMDIXXGL    2782
# UPJKNMIDRB    2782
# VEWPPXWTWS    2782
# BIBIOOIHA     2782
# ZBYVQNRPUP    2782
# HWQKLKDVSB    2782
# GCPKFKSEWG    2782
# GHOAPVUVYL    2782
# NTMMOBBPEE    2782
# UPHDCCFDRL    2601
# POEZMGDXLN    2080
# FRBLLORNXN    1830
# AHSRVKIOLJ    1757
# DUVTZNWNAB    1166
# EFCRJFQTCD     272
# Name: Identifier, dtype: int64

# %%
df['Category'][df['Identifier'] == 'HWTFIGIXOL'].value_counts()
# Out:
# Ovens & Cooktops    2782
# Name: Category, dtype: int64

# %%
df['Category'][df['Identifier'] == 'ZTEIJGNYNC'].value_counts()
# Out:
# Ovens & Cooktops    2782
# Name: Category, dtype: int64

# %%
df['Category'][df['Identifier'] == 'AHSRVKIOLJ'].value_counts()
# Out:
# Water Heaters     1757
# Name: Category, dtype: int64

# %%
df['Maker'][df['Identifier'] == 'AHSRVKIOLJ'].value_counts()
# Out:
# Ikeda    1757
# Name: Maker, dtype: int64

# %%
df[(df['Sales'].isnull()) & (df['Identifier'] == 'AHSRVKIOLJ')]
# Out:
#              Date  Maker  Sales  Identifier        Category
# 51401  2014-09-18  Ikeda    NaN  AHSRVKIOLJ  Water Heaters
# 52148  2014-10-09  Ikeda    NaN  AHSRVKIOLJ  Water Heaters
# 54613  2014-12-18  Ikeda    NaN  AHSRVKIOLJ  Water Heaters
# 55786  2015-01-27  Ikeda    NaN  AHSRVKIOLJ  Water Heaters
# 57907  2015-03-30  Ikeda    NaN  AHSRVKIOLJ  Water Heaters
# ...           ...    ...    ...         ...             ...
# 129321 2020-11-18  Ikeda    NaN  AHSRVKIOLJ  Water Heaters
# 130855 2021-01-05  Ikeda    NaN  AHSRVKIOLJ  Water Heaters
# 132388 2021-02-17  Ikeda    NaN  AHSRVKIOLJ  Water Heaters
# 133298 2021-03-15  Ikeda    NaN  AHSRVKIOLJ  Water Heaters
# 134493 2021-04-16  Ikeda    NaN  AHSRVKIOLJ  Water Heaters
#
# [77 rows x 5 columns]

# %%
df[df['Identifier'] == 'AHSRVKIOLJ']
# Out:
#              Date  Maker  Sales  Identifier        Category
# 46181  2014-04-08  Ikeda  763.0  AHSRVKIOLJ  Water Heaters
# 46209  2014-04-09  Ikeda  759.0  AHSRVKIOLJ  Water Heaters
# 46273  2014-04-10  Ikeda  719.0  AHSRVKIOLJ  Water Heaters
# 46328  2014-04-11  Ikeda  752.0  AHSRVKIOLJ  Water Heaters
# 46358  2014-04-14  Ikeda  761.0  AHSRVKIOLJ  Water Heaters
# ...           ...    ...    ...         ...             ...
# 134726 2021-04-23  Ikeda  294.0  AHSRVKIOLJ  Water Heaters
# 134783 2021-04-26  Ikeda  298.0  AHSRVKIOLJ  Water Heaters
# 134822 2021-04-27  Ikeda  293.0  AHSRVKIOLJ  Water Heaters
# 134895 2021-04-28  Ikeda  298.0  AHSRVKIOLJ  Water Heaters
# 134932 2021-04-29  Ikeda  301.0  AHSRVKIOLJ  Water Heaters
#
# [1757 rows x 5 columns]

# %%
df.groupby(by='Identifier').mean().round(2)
# Out:
#                Sales
# Identifier
# AHSRVKIOLJ    672.01
# AVXSMNNRDX   3226.39
# BIBIOOIHA    1045.58
# DUVTZNWNAB    363.60
# ECQPIOYXZO   6546.64
# EFCRJFQTCD    324.19
# FRBLLORNXN    411.40
# FUWHINIXUA  16321.21
# FVDHIZGQRC  11404.04
# GCPKFKSEWG    431.47
# GHOAPVUVYL   1488.50
# GQUIAFQIRH    728.15
# HANYALJGGA   1292.15
# HWQKLKDVSB   2415.96
# HWTFIGIXOL  24478.66
# JYINACMKHE   1214.59
# LBABGBBMJJ   3241.14
# LFIEXBAPFQ   2795.55
# NTMMOBBPEE   5026.15
# POEZMGDXLN   1554.82
# RBRMDIXXGL   3065.76
# RVFWTWSMNU   5212.54
# TJLYGOSEBQ   3779.72
# UPHDCCFDRL    539.07
# UPJKNMIDRB   1720.72
# VEWPPXWTWS   1009.99
# VNZSEQOSNP   1384.86
# VUQUQMHODG   6814.94
# VZAQLWEGXU   1436.03
# WVJTPVZKAQ   1453.27
# XVIOZZOUTN   1114.32
# ZBYVQNRPUP    945.71
# ZJPMAJIMIT  18445.47
# ZJZZJNDFOZ   6836.80
# ZTEIJGNYNC    350.15
# ZWNGQMERMH   1079.23

# %%
df[(df['Category'] == 'Air Conditioners') & (df['Maker'] == 'Toshino')]
# Out:
# Empty DataFrame
# Columns: [Date, Maker, Sales, Identifier, Category]
# Index: []

# %%
df[(df['Category'].str.contains('Conditioners'))]
# Out:
#              Date      Maker   Sales  Identifier           Category
# 0      2010-02-15    Toshino  2143.0  RVFWTWSMNU  Air Conditioners
# 15     2010-02-15     Funami   756.0  HWQKLKDVSB  Air Conditioners
# 18     2010-02-15  Yoshikawa  1754.0  NTMMOBBPEE  Air Conditioners
# 53     2010-02-16     Funami   765.0  HWQKLKDVSB  Air Conditioners
# 58     2010-02-16  Yoshikawa  1792.0  NTMMOBBPEE  Air Conditioners
# ...           ...        ...     ...         ...                ...
# 134889 2021-04-28     Funami  4123.0  HWQKLKDVSB  Air Conditioners
# 134910 2021-04-28  Yoshikawa  5844.0  NTMMOBBPEE  Air Conditioners
# 134924 2021-04-29    Toshino  6211.0  RVFWTWSMNU  Air Conditioners
# 134942 2021-04-29     Funami  4158.0  HWQKLKDVSB  Air Conditioners
# 134948 2021-04-29  Yoshikawa  5899.0  NTMMOBBPEE  Air Conditioners
#
# [8346 rows x 5 columns]

# %%
df[df['Category'] == 'Rice Cookers']
# Out:
# Empty DataFrame
# Columns: [Date, Maker, Sales, Identifier, Category]
# Index: []

# %%
df[df['Category'] == 'Rice Cookers ']
# Out:
#              Date      Maker   Sales  Identifier       Category
# 24     2010-02-15      Ikeda   245.0  JYINACMKHE  Rice Cookers
# 26     2010-02-15   Furutani  2233.0  ZJZZJNDFOZ  Rice Cookers
# 41     2010-02-15    Toshino  3618.0  ECQPIOYXZO  Rice Cookers
# 43     2010-02-15  Matsumoto   425.0  TJLYGOSEBQ  Rice Cookers
# 62     2010-02-16    Toshino  3736.0  ECQPIOYXZO  Rice Cookers
# ...           ...        ...     ...         ...            ...
# 134908 2021-04-28  Matsumoto  7056.0  TJLYGOSEBQ  Rice Cookers
# 134915 2021-04-29    Toshino  6530.0  ECQPIOYXZO  Rice Cookers
# 134926 2021-04-29      Ikeda  1978.0  JYINACMKHE  Rice Cookers
# 134929 2021-04-29  Matsumoto  6894.0  TJLYGOSEBQ  Rice Cookers
# 134931 2021-04-29   Furutani  6061.0  ZJZZJNDFOZ  Rice Cookers
#
# [11130 rows x 5 columns]

# %%
df['Category'].value_counts()
# Out:
# Ovens & Cooktops     13910
# Rice Cookers         11130
# Refrigerators        11129
# Vacuum Cleaners      11128
# Televisions          10449
# Air Conditioners      8346
# Dishwashers           8165
# Water Heaters         7785
# Water Pumps           5565
# Washers & Dryers      5564
# Name: Category, dtype: int64

# %%
df['Category']
# Out:
# 0         Air Conditioners
# 2          Washers & Dryers
# 3           Refrigerators
# 4          Washers & Dryers
# 6           Refrigerators
#                 ...
# 134956     Ovens & Cooktops
# 134960     Washers & Dryers
# 134961     Vacuum Cleaners
# 134962         Water Pumps
# 134963        Televisions
# Name: Category, Length: 93171, dtype: object

# %%
df2
# Out:
#             Date      Category1 Category2 Category3      Maker   Sales  \
# 0     2010-04-01    Dishwashers       NaN       NaN     Nanase  4708.0
# 1     2010-04-01           Rice   Cookers       NaN      Ikeda   279.0
# 2     2010-04-01         Vacuum  Cleaners       NaN  Hayashida   149.0
# 3     2010-04-01          Water   Heaters       NaN   Furutani   614.0
# 4     2010-04-01  Refrigerators       NaN       NaN      Akaza  1122.0
# ...          ...            ...       ...       ...        ...     ...
# 2723  2010-06-30         Vacuum  Cleaners       NaN     Hisami   666.0
# 2724  2010-06-30          Water     Pumps       NaN  Yoshikawa  2171.0
# 2725  2010-06-30          Ovens         &  Cooktops      Akaza   566.0
# 2726  2010-06-30          Water     Pumps       NaN   Furutani  8749.0
# 2727  2010-06-30    Dishwashers       NaN       NaN   Katayama  1458.0
#
#       Identifier
# 0     AVXSMNNRDX
# 1     JYINACMKHE
# 2     GCPKFKSEWG
# 3     PF4KB33DVZ
# 4     XVIOZZOUTN
# ...          ...
# 2723  VNZSEQOSNP
# 2724  TLSY3MWMK8
# 2725  PHFB77Q5OA
# 2726  FVDHIZGQRC
# 2727  ZWNGQMERMH
#
# [2728 rows x 7 columns]

# %%
df2['Category1'].str[:-1]
# Out:
# 0         Dishwasher
# 1                Ric
# 2              Vacuu
# 3               Wate
# 4       Refrigerator
#             ...
# 2723           Vacuu
# 2724            Wate
# 2725            Oven
# 2726            Wate
# 2727      Dishwasher
# Name: Category1, Length: 2728, dtype: object

# %%
df2['Category'] = ''

# %%
df2
# Out:
#             Date      Category1 Category2 Category3      Maker   Sales  \
# 0     2010-04-01    Dishwashers       NaN       NaN     Nanase  4708.0
# 1     2010-04-01           Rice   Cookers       NaN      Ikeda   279.0
# 2     2010-04-01         Vacuum  Cleaners       NaN  Hayashida   149.0
# 3     2010-04-01          Water   Heaters       NaN   Furutani   614.0
# 4     2010-04-01  Refrigerators       NaN       NaN      Akaza  1122.0
# ...          ...            ...       ...       ...        ...     ...
# 2723  2010-06-30         Vacuum  Cleaners       NaN     Hisami   666.0
# 2724  2010-06-30          Water     Pumps       NaN  Yoshikawa  2171.0
# 2725  2010-06-30          Ovens         &  Cooktops      Akaza   566.0
# 2726  2010-06-30          Water     Pumps       NaN   Furutani  8749.0
# 2727  2010-06-30    Dishwashers       NaN       NaN   Katayama  1458.0
#
#       Identifier Category
# 0     AVXSMNNRDX
# 1     JYINACMKHE
# 2     GCPKFKSEWG
# 3     PF4KB33DVZ
# 4     XVIOZZOUTN
# ...          ...      ...
# 2723  VNZSEQOSNP
# 2724  TLSY3MWMK8
# 2725  PHFB77Q5OA
# 2726  FVDHIZGQRC
# 2727  ZWNGQMERMH
#
# [2728 rows x 8 columns]

# %%
df2['Category'] = np.nan

# %%
df2['Category'] = df2['Category1'].mask(df2['Category2'].isnull(), df2['Category1'])

# %%
df2
# Out:
#             Date      Category1 Category2 Category3      Maker   Sales  \
# 0     2010-04-01    Dishwashers       NaN       NaN     Nanase  4708.0
# 1     2010-04-01           Rice   Cookers       NaN      Ikeda   279.0
# 2     2010-04-01         Vacuum  Cleaners       NaN  Hayashida   149.0
# 3     2010-04-01          Water   Heaters       NaN   Furutani   614.0
# 4     2010-04-01  Refrigerators       NaN       NaN      Akaza  1122.0
# ...          ...            ...       ...       ...        ...     ...
# 2723  2010-06-30         Vacuum  Cleaners       NaN     Hisami   666.0
# 2724  2010-06-30          Water     Pumps       NaN  Yoshikawa  2171.0
# 2725  2010-06-30          Ovens         &  Cooktops      Akaza   566.0
# 2726  2010-06-30          Water     Pumps       NaN   Furutani  8749.0
# 2727  2010-06-30    Dishwashers       NaN       NaN   Katayama  1458.0
#
#       Identifier       Category
# 0     AVXSMNNRDX    Dishwashers
# 1     JYINACMKHE           Rice
# 2     GCPKFKSEWG         Vacuum
# 3     PF4KB33DVZ          Water
# 4     XVIOZZOUTN  Refrigerators
# ...          ...            ...
# 2723  VNZSEQOSNP         Vacuum
# 2724  TLSY3MWMK8          Water
# 2725  PHFB77Q5OA          Ovens
# 2726  FVDHIZGQRC          Water
# 2727  ZWNGQMERMH    Dishwashers
#
# [2728 rows x 8 columns]

# %%
df2['Category2'].isnull()
# Out:
# 0        True
# 1       False
# 2       False
# 3       False
# 4        True
#         ...
# 2723    False
# 2724    False
# 2725    False
# 2726    False
# 2727     True
# Name: Category2, Length: 2728, dtype: bool

# %%
df2['Category'] = df2['Category'].mask((df2['Category2'].isnull()) & (df2['Category3'].isnull()), df2['Category1'])

# %%
df2
# Out:
#             Date      Category1 Category2 Category3      Maker   Sales  \
# 0     2010-04-01    Dishwashers       NaN       NaN     Nanase  4708.0
# 1     2010-04-01           Rice   Cookers       NaN      Ikeda   279.0
# 2     2010-04-01         Vacuum  Cleaners       NaN  Hayashida   149.0
# 3     2010-04-01          Water   Heaters       NaN   Furutani   614.0
# 4     2010-04-01  Refrigerators       NaN       NaN      Akaza  1122.0
# ...          ...            ...       ...       ...        ...     ...
# 2723  2010-06-30         Vacuum  Cleaners       NaN     Hisami   666.0
# 2724  2010-06-30          Water     Pumps       NaN  Yoshikawa  2171.0
# 2725  2010-06-30          Ovens         &  Cooktops      Akaza   566.0
# 2726  2010-06-30          Water     Pumps       NaN   Furutani  8749.0
# 2727  2010-06-30    Dishwashers       NaN       NaN   Katayama  1458.0
#
#       Identifier       Category
# 0     AVXSMNNRDX    Dishwashers
# 1     JYINACMKHE            NaN
# 2     GCPKFKSEWG            NaN
# 3     PF4KB33DVZ            NaN
# 4     XVIOZZOUTN  Refrigerators
# ...          ...            ...
# 2723  VNZSEQOSNP            NaN
# 2724  TLSY3MWMK8            NaN
# 2725  PHFB77Q5OA            NaN
# 2726  FVDHIZGQRC            NaN
# 2727  ZWNGQMERMH    Dishwashers
#
# [2728 rows x 8 columns]

# %%
df2['Category'] = df2['Category'].mask((df2['Category2'].notnull()) & (df2['Category3'].isnull()), df2['Category1'] + ' ' + df2['Category2'])

# %%
df2
# Out:
#             Date      Category1 Category2 Category3      Maker   Sales  \
# 0     2010-04-01    Dishwashers       NaN       NaN     Nanase  4708.0
# 1     2010-04-01           Rice   Cookers       NaN      Ikeda   279.0
# 2     2010-04-01         Vacuum  Cleaners       NaN  Hayashida   149.0
# 3     2010-04-01          Water   Heaters       NaN   Furutani   614.0
# 4     2010-04-01  Refrigerators       NaN       NaN      Akaza  1122.0
# ...          ...            ...       ...       ...        ...     ...
# 2723  2010-06-30         Vacuum  Cleaners       NaN     Hisami   666.0
# 2724  2010-06-30          Water     Pumps       NaN  Yoshikawa  2171.0
# 2725  2010-06-30          Ovens         &  Cooktops      Akaza   566.0
# 2726  2010-06-30          Water     Pumps       NaN   Furutani  8749.0
# 2727  2010-06-30    Dishwashers       NaN       NaN   Katayama  1458.0
#
#       Identifier         Category
# 0     AVXSMNNRDX      Dishwashers
# 1     JYINACMKHE     Rice Cookers
# 2     GCPKFKSEWG  Vacuum Cleaners
# 3     PF4KB33DVZ    Water Heaters
# 4     XVIOZZOUTN    Refrigerators
# ...          ...              ...
# 2723  VNZSEQOSNP  Vacuum Cleaners
# 2724  TLSY3MWMK8      Water Pumps
# 2725  PHFB77Q5OA              NaN
# 2726  FVDHIZGQRC      Water Pumps
# 2727  ZWNGQMERMH      Dishwashers
#
# [2728 rows x 8 columns]

# %%
df2['Category'] = df2['Category'].mask((df2['Category2'].notnull()) & (df2['Category3'].notnull()), df2['Category1'] + ' ' + df2['Category2'])

# %%
df2
# Out:
#             Date      Category1 Category2 Category3      Maker   Sales  \
# 0     2010-04-01    Dishwashers       NaN       NaN     Nanase  4708.0
# 1     2010-04-01           Rice   Cookers       NaN      Ikeda   279.0
# 2     2010-04-01         Vacuum  Cleaners       NaN  Hayashida   149.0
# 3     2010-04-01          Water   Heaters       NaN   Furutani   614.0
# 4     2010-04-01  Refrigerators       NaN       NaN      Akaza  1122.0
# ...          ...            ...       ...       ...        ...     ...
# 2723  2010-06-30         Vacuum  Cleaners       NaN     Hisami   666.0
# 2724  2010-06-30          Water     Pumps       NaN  Yoshikawa  2171.0
# 2725  2010-06-30          Ovens         &  Cooktops      Akaza   566.0
# 2726  2010-06-30          Water     Pumps       NaN   Furutani  8749.0
# 2727  2010-06-30    Dishwashers       NaN       NaN   Katayama  1458.0
#
#       Identifier         Category
# 0     AVXSMNNRDX      Dishwashers
# 1     JYINACMKHE     Rice Cookers
# 2     GCPKFKSEWG  Vacuum Cleaners
# 3     PF4KB33DVZ    Water Heaters
# 4     XVIOZZOUTN    Refrigerators
# ...          ...              ...
# 2723  VNZSEQOSNP  Vacuum Cleaners
# 2724  TLSY3MWMK8      Water Pumps
# 2725  PHFB77Q5OA          Ovens &
# 2726  FVDHIZGQRC      Water Pumps
# 2727  ZWNGQMERMH      Dishwashers
#
# [2728 rows x 8 columns]

# %%
df2[df2['Category'] == 'Air Conditioners']
# Out:
#             Date Category1     Category2 Category3      Maker   Sales  \
# 27    2010-04-01       Air  Conditioners       NaN  Yoshikawa  1788.0
# 29    2010-04-01       Air  Conditioners       NaN     Funami   876.0
# 33    2010-04-01       Air  Conditioners       NaN      Akaza  1390.0
# 38    2010-04-01       Air  Conditioners       NaN    Toshino  2591.0
# 57    2010-04-05       Air  Conditioners       NaN      Akaza  1518.0
# ...          ...       ...           ...       ...        ...     ...
# 2658  2010-06-29       Air  Conditioners       NaN      Akaza  1550.0
# 2692  2010-06-30       Air  Conditioners       NaN      Akaza  1627.0
# 2699  2010-06-30       Air  Conditioners       NaN     Funami   929.0
# 2714  2010-06-30       Air  Conditioners       NaN  Yoshikawa  1770.0
# 2720  2010-06-30       Air  Conditioners       NaN    Toshino  2957.0
#
#       Identifier          Category
# 27    NTMMOBBPEE  Air Conditioners
# 29    HWQKLKDVSB  Air Conditioners
# 33    IVOI4I03JA  Air Conditioners
# 38    RVFWTWSMNU  Air Conditioners
# 57    IVOI4I03JA  Air Conditioners
# ...          ...               ...
# 2658  IVOI4I03JA  Air Conditioners
# 2692  IVOI4I03JA  Air Conditioners
# 2699  HWQKLKDVSB  Air Conditioners
# 2714  NTMMOBBPEE  Air Conditioners
# 2720  RVFWTWSMNU  Air Conditioners
#
# [248 rows x 8 columns]

# %% [markdown]
# # -----
# ## Checkpoint
# # -----

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import glob
import re
import warnings
warnings.filterwarnings('ignore')

# %%
path = 'D:/complete-proj/2021/07/apply/ilmuone-data/dataset'
all_files = glob.glob(path + '/*.csv')

# %%
lst = []
for filename in all_files:
    data = pd.read_csv(filename, index_col=None, header=0)
    lst.append(data)

# %%
df = pd.concat(lst, axis=0, ignore_index=True)

# %%
df
# Out:
#               Date      Category1     Category2 Category3      Maker    Sales  \
# 0       2010-02-15            Air  Conditioners       NaN    Toshino   2143.0
# 1       2010-02-15          Water       Heaters       NaN   Furutani    567.0
# 2       2010-02-15        Washers             &    Dryers      Akaza   3515.0
# 3       2010-02-15  Refrigerators           NaN       NaN      Akaza    687.0
# 4       2010-02-15        Washers             &    Dryers    Shimada    435.0
# ...            ...            ...           ...       ...        ...      ...
# 134959  2021-04-29            Air  Conditioners       NaN      Akaza   1609.0
# 134960  2021-04-29        Washers             &    Dryers      Akaza   5422.0
# 134961  2021-04-29         Vacuum      Cleaners       NaN  Hayashida    539.0
# 134962  2021-04-29          Water         Pumps       NaN   Furutani  10547.0
# 134963  2021-04-29    Televisions           NaN       NaN     Kikuma    805.0
#
#         Identifier
# 0       RVFWTWSMNU
# 1       PF4KB33DVZ
# 2       VUQUQMHODG
# 3       XVIOZZOUTN
# 4       RBRMDIXXGL
# ...            ...
# 134959  IVOI4I03JA
# 134960  VUQUQMHODG
# 134961  GCPKFKSEWG
# 134962  FVDHIZGQRC
# 134963  FRBLLORNXN
#
# [134964 rows x 7 columns]

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
bool_cat2isnull_cat3isnull = (df['Category2'].isnull()) & (df['Category3'].isnull())
bool_cat2notnull_cat3isnull = (df['Category2'].notnull()) & (df['Category3'].isnull())
bool_cat2notnull_cat3notnull = (df['Category2'].notnull()) & (df['Category3'].notnull())

# %%
df['Category'] = np.nan

# %%
df['Category'] = df['Category'].mask(bool_cat2isnull_cat3isnull, df['Category1'])
df['Category'] = df['Category'].mask(bool_cat2notnull_cat3isnull, df['Category1'] + ' ' + df['Category2'])
df['Category'] = df['Category'].mask(bool_cat2notnull_cat3notnull, df['Category1'] + ' ' + df['Category2'] + ' ' + df['Category3'])

# %%
df
# Out:
#              Date      Category1     Category2 Category3      Maker    Sales  \
# 0      2010-02-15            Air  Conditioners       NaN    Toshino   2143.0
# 1      2010-02-15          Water       Heaters       NaN   Furutani    567.0
# 2      2010-02-15        Washers             &    Dryers      Akaza   3515.0
# 3      2010-02-15  Refrigerators           NaN       NaN      Akaza    687.0
# 4      2010-02-15        Washers             &    Dryers    Shimada    435.0
# ...           ...            ...           ...       ...        ...      ...
# 134959 2021-04-29            Air  Conditioners       NaN      Akaza   1609.0
# 134960 2021-04-29        Washers             &    Dryers      Akaza   5422.0
# 134961 2021-04-29         Vacuum      Cleaners       NaN  Hayashida    539.0
# 134962 2021-04-29          Water         Pumps       NaN   Furutani  10547.0
# 134963 2021-04-29    Televisions           NaN       NaN     Kikuma    805.0
#
#         Identifier          Category
# 0       RVFWTWSMNU  Air Conditioners
# 1       PF4KB33DVZ     Water Heaters
# 2       VUQUQMHODG  Washers & Dryers
# 3       XVIOZZOUTN     Refrigerators
# 4       RBRMDIXXGL  Washers & Dryers
# ...            ...               ...
# 134959  IVOI4I03JA  Air Conditioners
# 134960  VUQUQMHODG  Washers & Dryers
# 134961  GCPKFKSEWG   Vacuum Cleaners
# 134962  FVDHIZGQRC       Water Pumps
# 134963  FRBLLORNXN       Televisions
#
# [134964 rows x 8 columns]

# %%
df[df['Category'] == 'Televisions']
# Out:
#              Date    Category1 Category2 Category3     Maker   Sales  \
# 17     2010-02-15  Televisions       NaN       NaN   Shimada   129.0
# 20     2010-02-15  Televisions       NaN       NaN   Okamoto   322.0
# 42     2010-02-15  Televisions       NaN       NaN  Katayama    83.0
# 45     2010-02-16  Televisions       NaN       NaN  Katayama    68.0
# 83     2010-02-16  Televisions       NaN       NaN   Okamoto   316.0
# ...           ...          ...       ...       ...       ...     ...
# 134919 2021-04-29  Televisions       NaN       NaN   Shimada  2652.0
# 134925 2021-04-29  Televisions       NaN       NaN   Okamoto  1462.0
# 134935 2021-04-29  Televisions       NaN       NaN  Katayama  2229.0
# 134950 2021-04-29  Televisions       NaN       NaN    Nanase   313.0
# 134963 2021-04-29  Televisions       NaN       NaN    Kikuma   805.0
#
#         Identifier     Category
# 17      GHOAPVUVYL  Televisions
# 20      HANYALJGGA  Televisions
# 42      VZAQLWEGXU  Televisions
# 45      VZAQLWEGXU  Televisions
# 83      HANYALJGGA  Televisions
# ...            ...          ...
# 134919  GHOAPVUVYL  Televisions
# 134925  HANYALJGGA  Televisions
# 134935  VZAQLWEGXU  Televisions
# 134950  EFCRJFQTCD  Televisions
# 134963  FRBLLORNXN  Televisions
#
# [10449 rows x 8 columns]

# %%
df = df[~df['Identifier'].str.contains(r'[0-9]')]

# %%
df = df.drop(['Category1', 'Category2', 'Category3'], axis=1)

# %%
df
# Out:
#              Date      Maker    Sales  Identifier          Category
# 0      2010-02-15    Toshino   2143.0  RVFWTWSMNU  Air Conditioners
# 2      2010-02-15      Akaza   3515.0  VUQUQMHODG  Washers & Dryers
# 3      2010-02-15      Akaza    687.0  XVIOZZOUTN     Refrigerators
# 4      2010-02-15    Shimada    435.0  RBRMDIXXGL  Washers & Dryers
# 6      2010-02-15     Funami    726.0   BIBIOOIHA     Refrigerators
# ...           ...        ...      ...         ...               ...
# 134956 2021-04-29    Shimada   1258.0  WVJTPVZKAQ  Ovens & Cooktops
# 134960 2021-04-29      Akaza   5422.0  VUQUQMHODG  Washers & Dryers
# 134961 2021-04-29  Hayashida    539.0  GCPKFKSEWG   Vacuum Cleaners
# 134962 2021-04-29   Furutani  10547.0  FVDHIZGQRC       Water Pumps
# 134963 2021-04-29     Kikuma    805.0  FRBLLORNXN       Televisions
#
# [93171 rows x 5 columns]

# %%
df.to_csv('df-clean-01.csv', index=False)

# %%
# Fill sales groupby identifier

# %% [markdown]
# # ----
# ## Checkpoint
# # ----

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 93171 entries, 0 to 134963
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Date        93171 non-null  datetime64[ns]
#  1   Maker       93171 non-null  object
#  2   Sales       89498 non-null  float64
#  3   Identifier  93171 non-null  object
#  4   Category    93171 non-null  object
# dtypes: datetime64[ns](1), float64(1), object(3)
# memory usage: 4.3+ MB

# %%
df.groupby(by='Identifier').mean().round(2)
# Out:
#                Sales
# Identifier
# AHSRVKIOLJ    672.01
# AVXSMNNRDX   3226.39
# BIBIOOIHA    1045.58
# DUVTZNWNAB    363.60
# ECQPIOYXZO   6546.64
# EFCRJFQTCD    324.19
# FRBLLORNXN    411.40
# FUWHINIXUA  16321.21
# FVDHIZGQRC  11404.04
# GCPKFKSEWG    431.47
# GHOAPVUVYL   1488.50
# GQUIAFQIRH    728.15
# HANYALJGGA   1292.15
# HWQKLKDVSB   2415.96
# HWTFIGIXOL  24478.66
# JYINACMKHE   1214.59
# LBABGBBMJJ   3241.14
# LFIEXBAPFQ   2795.55
# NTMMOBBPEE   5026.15
# POEZMGDXLN   1554.82
# RBRMDIXXGL   3065.76
# RVFWTWSMNU   5212.54
# TJLYGOSEBQ   3779.72
# UPHDCCFDRL    539.07
# UPJKNMIDRB   1720.72
# VEWPPXWTWS   1009.99
# VNZSEQOSNP   1384.86
# VUQUQMHODG   6814.94
# VZAQLWEGXU   1436.03
# WVJTPVZKAQ   1453.27
# XVIOZZOUTN   1114.32
# ZBYVQNRPUP    945.71
# ZJPMAJIMIT  18445.47
# ZJZZJNDFOZ   6836.80
# ZTEIJGNYNC    350.15
# ZWNGQMERMH   1079.23

# %%
df.isnull().sum()
# Out:
# Date             0
# Maker            0
# Sales         3673
# Identifier       0
# Category         0
# dtype: int64

# %%
df[df['Sales'].isnull()]
# Out:
#              Date      Maker  Sales  Identifier          Category
# 27     2010-02-15      Omuro    NaN  HWTFIGIXOL  Ovens & Cooktops
# 54     2010-02-16    Sugiura    NaN  UPJKNMIDRB     Water Heaters
# 129    2010-02-17    Toshino    NaN  RVFWTWSMNU  Air Conditioners
# 189    2010-02-19      Akaza    NaN  ZBYVQNRPUP   Vacuum Cleaners
# 224    2010-02-22   Katayama    NaN  ZWNGQMERMH       Dishwashers
# ...           ...        ...    ...         ...               ...
# 134869 2021-04-28     Funami    NaN  VEWPPXWTWS   Vacuum Cleaners
# 134877 2021-04-28      Akaza    NaN  VUQUQMHODG  Washers & Dryers
# 134885 2021-04-28  Yoshikawa    NaN  DUVTZNWNAB     Water Heaters
# 134918 2021-04-29      Akaza    NaN  XVIOZZOUTN     Refrigerators
# 134928 2021-04-29    Shimada    NaN  RBRMDIXXGL  Washers & Dryers
#
# [3673 rows x 5 columns]

# %%
df['Sales'].isnull()
# Out:
# 0         False
# 2         False
# 3         False
# 4         False
# 6         False
#           ...
# 134956    False
# 134960    False
# 134961    False
# 134962    False
# 134963    False
# Name: Sales, Length: 93171, dtype: bool

# %%
for index, values in zip(df.groupby(by='Identifier').mean().round(2).index, df.groupby(by='Identifier').mean().round(2).values):
    print(index, values)
# Out:
# AHSRVKIOLJ [672.01]
# AVXSMNNRDX [3226.39]
# BIBIOOIHA [1045.58]
# DUVTZNWNAB [363.6]
# ECQPIOYXZO [6546.64]
# EFCRJFQTCD [324.19]
# FRBLLORNXN [411.4]
# FUWHINIXUA [16321.21]
# FVDHIZGQRC [11404.04]
# GCPKFKSEWG [431.47]
# GHOAPVUVYL [1488.5]
# GQUIAFQIRH [728.15]
# HANYALJGGA [1292.15]
# HWQKLKDVSB [2415.96]
# HWTFIGIXOL [24478.66]
# JYINACMKHE [1214.59]
# LBABGBBMJJ [3241.14]
# LFIEXBAPFQ [2795.55]
# NTMMOBBPEE [5026.15]
# POEZMGDXLN [1554.82]
# RBRMDIXXGL [3065.76]
# RVFWTWSMNU [5212.54]
# TJLYGOSEBQ [3779.72]
# UPHDCCFDRL [539.07]
# UPJKNMIDRB [1720.72]
# VEWPPXWTWS [1009.99]
# VNZSEQOSNP [1384.86]
# VUQUQMHODG [6814.94]
# VZAQLWEGXU [1436.03]
# WVJTPVZKAQ [1453.27]
# XVIOZZOUTN [1114.32]
# ZBYVQNRPUP [945.71]
# ZJPMAJIMIT [18445.47]
# ZJZZJNDFOZ [6836.8]
# ZTEIJGNYNC [350.15]
# ZWNGQMERMH [1079.23]

# %%
grpby_id = df.groupby(by='Identifier').mean().round(2)

# %%
grpby_id.index
# Out:
# Index(['AHSRVKIOLJ', 'AVXSMNNRDX', 'BIBIOOIHA', 'DUVTZNWNAB', 'ECQPIOYXZO',
#        'EFCRJFQTCD', 'FRBLLORNXN', 'FUWHINIXUA', 'FVDHIZGQRC', 'GCPKFKSEWG',
#        'GHOAPVUVYL', 'GQUIAFQIRH', 'HANYALJGGA', 'HWQKLKDVSB', 'HWTFIGIXOL',
#        'JYINACMKHE', 'LBABGBBMJJ', 'LFIEXBAPFQ', 'NTMMOBBPEE', 'POEZMGDXLN',
#        'RBRMDIXXGL', 'RVFWTWSMNU', 'TJLYGOSEBQ', 'UPHDCCFDRL', 'UPJKNMIDRB',
#        'VEWPPXWTWS', 'VNZSEQOSNP', 'VUQUQMHODG', 'VZAQLWEGXU', 'WVJTPVZKAQ',
#        'XVIOZZOUTN', 'ZBYVQNRPUP', 'ZJPMAJIMIT', 'ZJZZJNDFOZ', 'ZTEIJGNYNC',
#        'ZWNGQMERMH'],
#       dtype='object', name='Identifier')

# %%
for index, values in zip(grpby_id.index, grpby_id.values):
    print(index, values[0])
# Out:
# AHSRVKIOLJ 672.01
# AVXSMNNRDX 3226.39
# BIBIOOIHA 1045.58
# DUVTZNWNAB 363.6
# ECQPIOYXZO 6546.64
# EFCRJFQTCD 324.19
# FRBLLORNXN 411.4
# FUWHINIXUA 16321.21
# FVDHIZGQRC 11404.04
# GCPKFKSEWG 431.47
# GHOAPVUVYL 1488.5
# GQUIAFQIRH 728.15
# HANYALJGGA 1292.15
# HWQKLKDVSB 2415.96
# HWTFIGIXOL 24478.66
# JYINACMKHE 1214.59
# LBABGBBMJJ 3241.14
# LFIEXBAPFQ 2795.55
# NTMMOBBPEE 5026.15
# POEZMGDXLN 1554.82
# RBRMDIXXGL 3065.76
# RVFWTWSMNU 5212.54
# TJLYGOSEBQ 3779.72
# UPHDCCFDRL 539.07
# UPJKNMIDRB 1720.72
# VEWPPXWTWS 1009.99
# VNZSEQOSNP 1384.86
# VUQUQMHODG 6814.94
# VZAQLWEGXU 1436.03
# WVJTPVZKAQ 1453.27
# XVIOZZOUTN 1114.32
# ZBYVQNRPUP 945.71
# ZJPMAJIMIT 18445.47
# ZJZZJNDFOZ 6836.8
# ZTEIJGNYNC 350.15
# ZWNGQMERMH 1079.23

# %%
df['Identifier'].nunique()
# Out:
# 36

# %%
df['Identifier'][df['Sales'].isnull()].nunique()
# Out:
# 36

# %%
df['Identifier'][df['Sales'].isnull()].value_counts()
# Out:
# WVJTPVZKAQ    135
# RVFWTWSMNU    134
# NTMMOBBPEE    126
# GQUIAFQIRH    126
# RBRMDIXXGL    124
# ZJZZJNDFOZ    124
# GCPKFKSEWG    119
# HWTFIGIXOL    118
# JYINACMKHE    117
# GHOAPVUVYL    113
# ZBYVQNRPUP    112
# VUQUQMHODG    112
# LBABGBBMJJ    110
# HANYALJGGA    109
# ZWNGQMERMH    108
# VNZSEQOSNP    107
# VEWPPXWTWS    106
# HWQKLKDVSB    105
# ZJPMAJIMIT    104
# TJLYGOSEBQ    104
# ECQPIOYXZO    104
# VZAQLWEGXU    103
# BIBIOOIHA     103
# XVIOZZOUTN    101
# ZTEIJGNYNC    100
# FUWHINIXUA    100
# FVDHIZGQRC     98
# AVXSMNNRDX     94
# UPJKNMIDRB     94
# UPHDCCFDRL     94
# LFIEXBAPFQ     93
# AHSRVKIOLJ     77
# POEZMGDXLN     73
# FRBLLORNXN     69
# DUVTZNWNAB     51
# EFCRJFQTCD      6
# Name: Identifier, dtype: int64

# %%
# for identifier, sales_mean in zip(grpby_id.index, grpby_id.values):
#     df['Sales'] = df['Sales'].mask()

# %%
df[(df['Sales'].isnull()) & (df['Identifier'] == 'WVJTPVZKAQ')]
# Out:
#              Date    Maker  Sales  Identifier          Category
# 3427   2010-06-09  Shimada    NaN  WVJTPVZKAQ  Ovens & Cooktops
# 3436   2010-06-10  Shimada    NaN  WVJTPVZKAQ  Ovens & Cooktops
# 3845   2010-06-23  Shimada    NaN  WVJTPVZKAQ  Ovens & Cooktops
# 6198   2010-09-07  Shimada    NaN  WVJTPVZKAQ  Ovens & Cooktops
# 6313   2010-09-17  Shimada    NaN  WVJTPVZKAQ  Ovens & Cooktops
# ...           ...      ...    ...         ...               ...
# 130589 2020-12-23  Shimada    NaN  WVJTPVZKAQ  Ovens & Cooktops
# 131984 2021-02-04  Shimada    NaN  WVJTPVZKAQ  Ovens & Cooktops
# 133526 2021-03-22  Shimada    NaN  WVJTPVZKAQ  Ovens & Cooktops
# 133573 2021-03-23  Shimada    NaN  WVJTPVZKAQ  Ovens & Cooktops
# 134298 2021-04-13  Shimada    NaN  WVJTPVZKAQ  Ovens & Cooktops
#
# [135 rows x 5 columns]

# %%
(df['Sales'].isnull()) & (df['Identifier'] == 'WVJTPVZKAQ')
# Out:
# 0         False
# 2         False
# 3         False
# 4         False
# 6         False
#           ...
# 134956    False
# 134960    False
# 134961    False
# 134962    False
# 134963    False
# Length: 93171, dtype: bool

# %%
df['Sales'].mask((df['Sales'].isnull()) & (df['Identifier'] == 'AHSRVKIOLJ'), 672.01).value_counts()
# Out:
# 672.01      77
# 247.00      68
# 610.00      64
# 621.00      59
# 671.00      59
#             ..
# 7616.00      1
# 13534.00     1
# 20229.00     1
# 11840.00     1
# 10547.00     1
# Name: Sales, Length: 16370, dtype: int64

# %%
grpby_id.values[0]
# Out:
# array([672.01])

# %%
df[(df['Sales'].isnull()) & (df['Identifier'] == 'AHSRVKIOLJ')]
# Out:
#              Date  Maker  Sales  Identifier       Category
# 51401  2014-09-18  Ikeda    NaN  AHSRVKIOLJ  Water Heaters
# 52148  2014-10-09  Ikeda    NaN  AHSRVKIOLJ  Water Heaters
# 54613  2014-12-18  Ikeda    NaN  AHSRVKIOLJ  Water Heaters
# 55786  2015-01-27  Ikeda    NaN  AHSRVKIOLJ  Water Heaters
# 57907  2015-03-30  Ikeda    NaN  AHSRVKIOLJ  Water Heaters
# ...           ...    ...    ...         ...            ...
# 129321 2020-11-18  Ikeda    NaN  AHSRVKIOLJ  Water Heaters
# 130855 2021-01-05  Ikeda    NaN  AHSRVKIOLJ  Water Heaters
# 132388 2021-02-17  Ikeda    NaN  AHSRVKIOLJ  Water Heaters
# 133298 2021-03-15  Ikeda    NaN  AHSRVKIOLJ  Water Heaters
# 134493 2021-04-16  Ikeda    NaN  AHSRVKIOLJ  Water Heaters
#
# [77 rows x 5 columns]

# %%
for identifier, sales_mean in zip(grpby_id.index, grpby_id.values):
    df['Sales'] = df['Sales'].mask((df['Sales'].isnull()) & (df['Identifier'] == identifier),
                                   sales_mean)

# %%
df['Sales'][df['Identifier'] == 'AHSRVKIOLJ'].value_counts()
# Out:
# 672.01    77
# 584.00    11
# 374.00     8
# 247.00     7
# 828.00     7
#           ..
# 840.00     1
# 803.00     1
# 868.00     1
# 937.00     1
# 308.00     1
# Name: Sales, Length: 811, dtype: int64

# %%
df.isnull().sum()
# Out:
# Date          0
# Maker         0
# Sales         0
# Identifier    0
# Category      0
# dtype: int64

# %%
df['Sales'].value_counts()
# Out:
# 1453.27     135
# 5212.54     134
# 5026.15     126
# 728.15      126
# 3065.76     124
#            ...
# 7616.00       1
# 11840.00      1
# 18376.00      1
# 13534.00      1
# 10547.00      1
# Name: Sales, Length: 16405, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 93171 entries, 0 to 134963
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Date        93171 non-null  datetime64[ns]
#  1   Maker       93171 non-null  object
#  2   Sales       93171 non-null  float64
#  3   Identifier  93171 non-null  object
#  4   Category    93171 non-null  object
# dtypes: datetime64[ns](1), float64(1), object(3)
# memory usage: 4.3+ MB

# %%
df.to_csv('df-clean-02.csv', index=False)

# %%
df
# Out:
#              Date      Maker    Sales  Identifier          Category
# 0      2010-02-15    Toshino   2143.0  RVFWTWSMNU  Air Conditioners
# 2      2010-02-15      Akaza   3515.0  VUQUQMHODG  Washers & Dryers
# 3      2010-02-15      Akaza    687.0  XVIOZZOUTN     Refrigerators
# 4      2010-02-15    Shimada    435.0  RBRMDIXXGL  Washers & Dryers
# 6      2010-02-15     Funami    726.0   BIBIOOIHA     Refrigerators
# ...           ...        ...      ...         ...               ...
# 134956 2021-04-29    Shimada   1258.0  WVJTPVZKAQ  Ovens & Cooktops
# 134960 2021-04-29      Akaza   5422.0  VUQUQMHODG  Washers & Dryers
# 134961 2021-04-29  Hayashida    539.0  GCPKFKSEWG   Vacuum Cleaners
# 134962 2021-04-29   Furutani  10547.0  FVDHIZGQRC       Water Pumps
# 134963 2021-04-29     Kikuma    805.0  FRBLLORNXN       Televisions
#
# [93171 rows x 5 columns]

# %%
df = df[['Date', 'Category', 'Maker', 'Sales', 'Identifier']]

# %%
df.to_csv('df-clean-02.csv', index=False)

# %%
df.describe()
# Out:
#               Sales
# count  93171.000000
# mean    4146.444172
# std     6254.450771
# min       62.000000
# 25%      801.000000
# 50%     1691.000000
# 75%     4892.000000
# max    56785.000000

# %%
sns.boxplot(data=df, x='Sales')
# Out:
# <AxesSubplot:xlabel='Sales'>

# %%
df[df['Sales'] > 4800]
# Out:
#              Date          Category      Maker     Sales  Identifier
# 27     2010-02-15  Ovens & Cooktops      Omuro  24478.66  HWTFIGIXOL
# 39     2010-02-15       Water Pumps   Furutani   7781.00  FVDHIZGQRC
# 40     2010-02-15       Water Pumps     Funami  13087.00  ZJPMAJIMIT
# 46     2010-02-16       Water Pumps   Furutani   7853.00  FVDHIZGQRC
# 69     2010-02-16  Ovens & Cooktops      Omuro  31022.00  HWTFIGIXOL
# ...           ...               ...        ...       ...         ...
# 134931 2021-04-29      Rice Cookers   Furutani   6061.00  ZJZZJNDFOZ
# 134948 2021-04-29  Air Conditioners  Yoshikawa   5899.00  NTMMOBBPEE
# 134955 2021-04-29       Water Pumps     Funami  13112.00  ZJPMAJIMIT
# 134960 2021-04-29  Washers & Dryers      Akaza   5422.00  VUQUQMHODG
# 134962 2021-04-29       Water Pumps   Furutani  10547.00  FVDHIZGQRC
#
# [23719 rows x 5 columns]

# %%
sns.displot(data=df, x='Sales');

# %%
sns.displot(data=df[df['Sales'] < 20000], x='Sales');

# %%
df[df['Sales'] < 20000]
# Out:
#              Date          Category      Maker    Sales  Identifier
# 0      2010-02-15  Air Conditioners    Toshino   2143.0  RVFWTWSMNU
# 2      2010-02-15  Washers & Dryers      Akaza   3515.0  VUQUQMHODG
# 3      2010-02-15     Refrigerators      Akaza    687.0  XVIOZZOUTN
# 4      2010-02-15  Washers & Dryers    Shimada    435.0  RBRMDIXXGL
# 6      2010-02-15     Refrigerators     Funami    726.0   BIBIOOIHA
# ...           ...               ...        ...      ...         ...
# 134956 2021-04-29  Ovens & Cooktops    Shimada   1258.0  WVJTPVZKAQ
# 134960 2021-04-29  Washers & Dryers      Akaza   5422.0  VUQUQMHODG
# 134961 2021-04-29   Vacuum Cleaners  Hayashida    539.0  GCPKFKSEWG
# 134962 2021-04-29       Water Pumps   Furutani  10547.0  FVDHIZGQRC
# 134963 2021-04-29       Televisions     Kikuma    805.0  FRBLLORNXN
#
# [89759 rows x 5 columns]

# %%
# sampling, plot before after sampling

# %%
df['Date'].value_counts()
# Out:
# 2021-04-29    36
# 2020-08-03    36
# 2020-07-23    36
# 2020-07-24    36
# 2020-07-27    36
#               ..
# 2010-08-05    30
# 2010-08-04    30
# 2010-02-15    30
# 2019-06-19     4
# 2020-12-09     2
# Name: Date, Length: 2784, dtype: int64

# %%
df[(df['Date'].dt.year == 2021) & (df['Date'].dt.month == 4)]
# Out:
#              Date          Category      Maker    Sales  Identifier
# 133924 2021-04-01     Water Heaters    Sugiura   1538.0  UPJKNMIDRB
# 133925 2021-04-01  Air Conditioners  Yoshikawa   5691.0  NTMMOBBPEE
# 133926 2021-04-01     Refrigerators      Omuro  31135.0  FUWHINIXUA
# 133927 2021-04-01   Vacuum Cleaners     Funami    927.0  VEWPPXWTWS
# 133928 2021-04-01  Washers & Dryers      Akaza   5343.0  VUQUQMHODG
# ...           ...               ...        ...      ...         ...
# 134956 2021-04-29  Ovens & Cooktops    Shimada   1258.0  WVJTPVZKAQ
# 134960 2021-04-29  Washers & Dryers      Akaza   5422.0  VUQUQMHODG
# 134961 2021-04-29   Vacuum Cleaners  Hayashida    539.0  GCPKFKSEWG
# 134962 2021-04-29       Water Pumps   Furutani  10547.0  FVDHIZGQRC
# 134963 2021-04-29       Televisions     Kikuma    805.0  FRBLLORNXN
#
# [720 rows x 5 columns]

# %%
ts = df[['Date', 'Sales']]

# %%
ts
# Out:
#              Date    Sales
# 0      2010-02-15   2143.0
# 2      2010-02-15   3515.0
# 3      2010-02-15    687.0
# 4      2010-02-15    435.0
# 6      2010-02-15    726.0
# ...           ...      ...
# 134956 2021-04-29   1258.0
# 134960 2021-04-29   5422.0
# 134961 2021-04-29    539.0
# 134962 2021-04-29  10547.0
# 134963 2021-04-29    805.0
#
# [93171 rows x 2 columns]

# %%
ts = ts.set_index('Date')

# %%
ts.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
ts = pd.read_csv('df-clean-02.csv', index_col='Date', parse_dates=True)

# %%
ts['Sales'].plot(figsize=(10, 10))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
from statsmodels.tsa.filters.hp_filter import hpfilter

# %%
gdp_cycle, gdp_trend = hpfilter(ts['Sales'], lamb=1600)

# %%
gdp_trend
# Out:
# Date
# 2010-02-15    1128.923317
# 2010-02-15    1204.275676
# 2010-02-15    1280.261833
# 2010-02-15    1358.959788
# 2010-02-15    1442.076754
#                  ...
# 2021-04-29    3481.486985
# 2021-04-29    3554.463066
# 2021-04-29    3628.492813
# 2021-04-29    3703.086477
# 2021-04-29    3775.823376
# Name: Sales_trend, Length: 93171, dtype: float64

# %%
ts['Sales']['2014-01-01':]
# Out:
# Date
# 2014-01-02    20325.0
# 2014-01-02      468.0
# 2014-01-02     1241.0
# 2014-01-02     1053.0
# 2014-01-02     6967.0
#                ...
# 2021-04-29     1258.0
# 2021-04-29     5422.0
# 2021-04-29      539.0
# 2021-04-29    10547.0
# 2021-04-29      805.0
# Name: Sales, Length: 63583, dtype: float64

# %%
ts['Sales']['2014-01-01':'2014-02-01'].plot(figsize=(10, 10))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
sns.lineplot(data=ts['Sales']['2014-01-01':'2015-01-01'])
# Out:
# <AxesSubplot:xlabel='Date', ylabel='Sales'>

# %%
df[(df['Date'].dt.year == 2014) & (df['Date'].dt.month >= 1) & (df['Date'].dt.month <=12)]
# Out:
#             Date          Category      Maker    Sales  Identifier
# 43038 2014-01-02       Water Pumps     Funami  20325.0  ZJPMAJIMIT
# 43039 2014-01-02       Dishwashers  Matsumoto    468.0  UPHDCCFDRL
# 43041 2014-01-02      Rice Cookers      Ikeda   1241.0  JYINACMKHE
# 43042 2014-01-02  Ovens & Cooktops    Shimada   1053.0  WVJTPVZKAQ
# 43043 2014-01-02  Washers & Dryers      Akaza   6967.0  VUQUQMHODG
# ...          ...               ...        ...      ...         ...
# 54923 2014-12-30  Ovens & Cooktops    Toshino   2491.0  LFIEXBAPFQ
# 54925 2014-12-30       Water Pumps     Funami  25002.0  ZJPMAJIMIT
# 54926 2014-12-30  Washers & Dryers      Akaza   7417.0  VUQUQMHODG
# 54927 2014-12-30     Refrigerators     Nanase    677.0  GQUIAFQIRH
# 54928 2014-12-30      Rice Cookers    Toshino   6764.0  ECQPIOYXZO
#
# [8231 rows x 5 columns]

# %%
df['Maker'][(df['Date'].dt.year == 2014) & (df['Date'].dt.month >= 1) & (df['Date'].dt.month <=12)].value_counts()
# Out:
# Funami       976
# Shimada      732
# Akaza        732
# Omuro        732
# Toshino      732
# Ikeda        667
# Matsumoto    488
# Furutani     488
# Sugiura      488
# Katayama     488
# Nanase       488
# Hayashida    244
# Kikuma       244
# Okamoto      244
# Yoshikawa    244
# Hisami       244
# Name: Maker, dtype: int64

# %%
df['Maker'][(df['Date'].dt.year == 2010) & (df['Date'].dt.month >= 1) & (df['Date'].dt.month <=12)].value_counts()
# Out:
# Funami       860
# Toshino      645
# Akaza        645
# Shimada      645
# Omuro        430
# Sugiura      430
# Ikeda        430
# Furutani     430
# Nanase       430
# Katayama     430
# Matsumoto    249
# Hisami       215
# Hayashida    215
# Yoshikawa    215
# Okamoto      215
# Name: Maker, dtype: int64

# %%
df['Sales'][(df['Date'].dt.year == 2010) & (df['Date'].dt.month >= 1) & (df['Date'].dt.month <=12)].value_counts(bins=10)
# Out:
# (13.074, 5560.5]      5611
# (5560.5, 11053.0]      430
# (11053.0, 16545.5]     144
# (16545.5, 22038.0]      84
# (33023.0, 38515.5]      82
# (38515.5, 44008.0]      55
# (49500.5, 54993.0]      32
# (44008.0, 49500.5]      20
# (27530.5, 33023.0]      18
# (22038.0, 27530.5]       8
# Name: Sales, dtype: int64

# %%
df['Sales'][(df['Date'].dt.year == 2010) & (df['Date'].dt.month >= 1) & (df['Date'].dt.month <=12)].sum()
# Out:
# 24888760.22

# %%
y10_1 = pd.read_csv('dataset/2010Q1.csv')
y10_1['Maker'].value_counts()
# Out:
# Akaza        186
# Funami       155
# Toshino      124
# Shimada      124
# Furutani      93
# Yoshikawa     93
# Sugiura       93
# Okamoto       62
# Hayashida     62
# Omuro         62
# Hisami        62
# Ikeda         62
# Nanase        62
# Katayama      62
# Kikuma        31
# Matsumoto     31
# Name: Maker, dtype: int64

# %%
y10_1
# Out:
#             Date      Category1     Category2 Category3     Maker    Sales  \
# 0     2010-02-15            Air  Conditioners       NaN   Toshino   2143.0
# 1     2010-02-15          Water       Heaters       NaN  Furutani    567.0
# 2     2010-02-15        Washers             &    Dryers     Akaza   3515.0
# 3     2010-02-15  Refrigerators           NaN       NaN     Akaza    687.0
# 4     2010-02-15        Washers             &    Dryers   Shimada    435.0
# ...          ...            ...           ...       ...       ...      ...
# 1359  2010-03-31          Ovens             &  Cooktops   Sugiura   4257.0
# 1360  2010-03-31          Ovens             &  Cooktops   Toshino   3483.0
# 1361  2010-03-31            Air  Conditioners       NaN   Toshino   2606.0
# 1362  2010-03-31         Vacuum      Cleaners       NaN   Toshino    450.0
# 1363  2010-03-31          Water         Pumps       NaN    Funami  14243.0
#
#       Identifier
# 0     RVFWTWSMNU
# 1     PF4KB33DVZ
# 2     VUQUQMHODG
# 3     XVIOZZOUTN
# 4     RBRMDIXXGL
# ...          ...
# 1359  LBABGBBMJJ
# 1360  LFIEXBAPFQ
# 1361  RVFWTWSMNU
# 1362  NHXJMH55UY
# 1363  ZJPMAJIMIT
#
# [1364 rows x 7 columns]

# %%
df['Maker'].nunique()
# Out:
# 16

# %%
df['Category'].nunique()
# Out:
# 10

# %%
df['Identifier'].nunique()
# Out:
# 36

# %%
df[df['Identifier'] == 'RVFWTWSMNU']
# Out:
#              Date          Category    Maker    Sales  Identifier
# 0      2010-02-15  Air Conditioners  Toshino  2143.00  RVFWTWSMNU
# 82     2010-02-16  Air Conditioners  Toshino  2164.00  RVFWTWSMNU
# 129    2010-02-17  Air Conditioners  Toshino  5212.54  RVFWTWSMNU
# 157    2010-02-18  Air Conditioners  Toshino  2214.00  RVFWTWSMNU
# 205    2010-02-19  Air Conditioners  Toshino  2224.00  RVFWTWSMNU
# ...           ...               ...      ...      ...         ...
# 134742 2021-04-23  Air Conditioners  Toshino  6147.00  RVFWTWSMNU
# 134768 2021-04-26  Air Conditioners  Toshino  5950.00  RVFWTWSMNU
# 134845 2021-04-27  Air Conditioners  Toshino  6035.00  RVFWTWSMNU
# 134867 2021-04-28  Air Conditioners  Toshino  6217.00  RVFWTWSMNU
# 134924 2021-04-29  Air Conditioners  Toshino  6211.00  RVFWTWSMNU
#
# [2782 rows x 5 columns]

# %%
y10_1[y10_1['Identifier'] == 'RVFWTWSMNU']
# Out:
#             Date Category1     Category2 Category3    Maker   Sales  \
# 0     2010-02-15       Air  Conditioners       NaN  Toshino  2143.0
# 82    2010-02-16       Air  Conditioners       NaN  Toshino  2164.0
# 129   2010-02-17       Air  Conditioners       NaN  Toshino     NaN
# 157   2010-02-18       Air  Conditioners       NaN  Toshino  2214.0
# 205   2010-02-19       Air  Conditioners       NaN  Toshino  2224.0
# 248   2010-02-22       Air  Conditioners       NaN  Toshino  2226.0
# 288   2010-02-23       Air  Conditioners       NaN  Toshino  2243.0
# 328   2010-02-24       Air  Conditioners       NaN  Toshino     NaN
# 391   2010-02-25       Air  Conditioners       NaN  Toshino  2220.0
# 431   2010-03-01       Air  Conditioners       NaN  Toshino  2216.0
# 481   2010-03-02       Air  Conditioners       NaN  Toshino  2211.0
# 502   2010-03-03       Air  Conditioners       NaN  Toshino  2177.0
# 541   2010-03-04       Air  Conditioners       NaN  Toshino  2204.0
# 588   2010-03-05       Air  Conditioners       NaN  Toshino  2182.0
# 618   2010-03-08       Air  Conditioners       NaN  Toshino  2241.0
# 661   2010-03-09       Air  Conditioners       NaN  Toshino  2289.0
# 712   2010-03-10       Air  Conditioners       NaN  Toshino     NaN
# 760   2010-03-11       Air  Conditioners       NaN  Toshino  2353.0
# 834   2010-03-12       Air  Conditioners       NaN  Toshino  2328.0
# 865   2010-03-15       Air  Conditioners       NaN  Toshino  2372.0
# 917   2010-03-17       Air  Conditioners       NaN  Toshino  2455.0
# 959   2010-03-18       Air  Conditioners       NaN  Toshino     NaN
# 1004  2010-03-19       Air  Conditioners       NaN  Toshino  2574.0
# 1042  2010-03-22       Air  Conditioners       NaN  Toshino  2476.0
# 1058  2010-03-23       Air  Conditioners       NaN  Toshino  2545.0
# 1124  2010-03-24       Air  Conditioners       NaN  Toshino  2677.0
# 1184  2010-03-25       Air  Conditioners       NaN  Toshino  2648.0
# 1204  2010-03-26       Air  Conditioners       NaN  Toshino  2660.0
# 1266  2010-03-29       Air  Conditioners       NaN  Toshino  2639.0
# 1310  2010-03-30       Air  Conditioners       NaN  Toshino  2685.0
# 1361  2010-03-31       Air  Conditioners       NaN  Toshino  2606.0
#
#       Identifier
# 0     RVFWTWSMNU
# 82    RVFWTWSMNU
# 129   RVFWTWSMNU
# 157   RVFWTWSMNU
# 205   RVFWTWSMNU
# 248   RVFWTWSMNU
# 288   RVFWTWSMNU
# 328   RVFWTWSMNU
# 391   RVFWTWSMNU
# 431   RVFWTWSMNU
# 481   RVFWTWSMNU
# 502   RVFWTWSMNU
# 541   RVFWTWSMNU
# 588   RVFWTWSMNU
# 618   RVFWTWSMNU
# 661   RVFWTWSMNU
# 712   RVFWTWSMNU
# 760   RVFWTWSMNU
# 834   RVFWTWSMNU
# 865   RVFWTWSMNU
# 917   RVFWTWSMNU
# 959   RVFWTWSMNU
# 1004  RVFWTWSMNU
# 1042  RVFWTWSMNU
# 1058  RVFWTWSMNU
# 1124  RVFWTWSMNU
# 1184  RVFWTWSMNU
# 1204  RVFWTWSMNU
# 1266  RVFWTWSMNU
# 1310  RVFWTWSMNU
# 1361  RVFWTWSMNU

# %%
path = 'D:/complete-proj/2021/07/apply/ilmuone-data/dataset'
all_files = glob.glob('dataset' + '/*.csv')

# %%
lst = []
for filename in all_files:
    data = pd.read_csv(filename, index_col=None, header=0)
    
    grpby_id = data.groupby(by='Identifier').mean().round(2)
    for identifier, sales_mean in zip(grpby_id.index, grpby_id.values):
        data['Sales'] = data['Sales'].mask((data['Sales'].isnull()) & (data['Identifier'] == identifier), sales_mean)
    
    lst.append(data)

# %%
df2 = pd.concat(lst, axis=0, ignore_index=True)

# %%
df2['Sales'].value_counts()
# Out:
# 622.0      87
# 404.0      80
# 610.0      80
# 624.0      80
# 621.0      79
#            ..
# 16172.0     1
# 8962.0      1
# 17511.0     1
# 16591.0     1
# 10547.0     1
# Name: Sales, Length: 18738, dtype: int64

# %%
y10_1
# Out:
#             Date      Category1     Category2 Category3     Maker    Sales  \
# 0     2010-02-15            Air  Conditioners       NaN   Toshino   2143.0
# 1     2010-02-15          Water       Heaters       NaN  Furutani    567.0
# 2     2010-02-15        Washers             &    Dryers     Akaza   3515.0
# 3     2010-02-15  Refrigerators           NaN       NaN     Akaza    687.0
# 4     2010-02-15        Washers             &    Dryers   Shimada    435.0
# ...          ...            ...           ...       ...       ...      ...
# 1359  2010-03-31          Ovens             &  Cooktops   Sugiura   4257.0
# 1360  2010-03-31          Ovens             &  Cooktops   Toshino   3483.0
# 1361  2010-03-31            Air  Conditioners       NaN   Toshino   2606.0
# 1362  2010-03-31         Vacuum      Cleaners       NaN   Toshino    450.0
# 1363  2010-03-31          Water         Pumps       NaN    Funami  14243.0
#
#       Identifier
# 0     RVFWTWSMNU
# 1     PF4KB33DVZ
# 2     VUQUQMHODG
# 3     XVIOZZOUTN
# 4     RBRMDIXXGL
# ...          ...
# 1359  LBABGBBMJJ
# 1360  LFIEXBAPFQ
# 1361  RVFWTWSMNU
# 1362  NHXJMH55UY
# 1363  ZJPMAJIMIT
#
# [1364 rows x 7 columns]

# %%
y10_1.groupby(by='Identifier').mean().round(2)
# Out:
#                Sales
# Identifier
# AHJK2FTTBH    202.61
# AVXSMNNRDX   4039.93
# BIBIOOIHA     796.40
# ECQPIOYXZO   3867.67
# FUFHZH9WRW    624.31
# FUWHINIXUA   5169.48
# FVDHIZGQRC   7638.55
# GCPKFKSEWG    144.31
# GHOAPVUVYL    125.53
# GQUIAFQIRH    398.84
# HANYALJGGA    333.17
# HWQKLKDVSB    767.90
# HWTFIGIXOL  33974.57
# IVOI4I03JA   1070.00
# JYINACMKHE    255.48
# KR2Q6QT8PE   1804.30
# KSNN8R2CCO    134.90
# LBABGBBMJJ   3935.07
# LFIEXBAPFQ   3239.07
# MXC7NMNBIW    120.35
# NHXJMH55UY    404.97
# NTMMOBBPEE   1769.74
# PF4KB33DVZ    589.97
# PHFB77Q5OA    491.00
# QFY2WV5LUE   1117.17
# RBRMDIXXGL    425.84
# RVFWTWSMNU   2369.33
# SFCA6H6QNU   1358.19
# TJLYGOSEBQ    457.34
# TLSY3MWMK8   1896.10
# UG2IU3EFWI   5006.41
# UPJKNMIDRB    314.83
# VEWPPXWTWS    386.33
# VNZSEQOSNP    613.18
# VUQUQMHODG   3875.43
# VZAQLWEGXU     76.03
# WVJTPVZKAQ   1860.74
# XVIOZZOUTN    779.77
# YPD6CTR0JA   1933.48
# ZBYVQNRPUP    365.21
# ZJPMAJIMIT  13839.20
# ZJZZJNDFOZ   2361.10
# ZTEIJGNYNC    349.93
# ZWNGQMERMH   1485.52

# %%
df2['Date'] = pd.to_datetime(df2['Date'])

# %%
# df2[(df2['Identifier'] == 'AHJK2FTTBH') & (df['Date'].dt.year == 2010) & (df['Date'].dt.month >= 1) & (df['Date'].dt.month <=12)]

# %%
df['Date'][df['Date'].between('2010-02-15', '2010-03-31')]
# Out:
# 0      2010-02-15
# 2      2010-02-15
# 3      2010-02-15
# 4      2010-02-15
# 6      2010-02-15
#           ...
# 1358   2010-03-31
# 1359   2010-03-31
# 1360   2010-03-31
# 1361   2010-03-31
# 1363   2010-03-31
# Name: Date, Length: 930, dtype: datetime64[ns]

# %%
df2[(df2['Identifier'] == 'RVFWTWSMNU') & (df2['Date'].between('2010-02-15', '2010-03-31'))]
# Out:
#            Date Category1     Category2 Category3    Maker    Sales  \
# 0    2010-02-15       Air  Conditioners       NaN  Toshino  2143.00
# 82   2010-02-16       Air  Conditioners       NaN  Toshino  2164.00
# 129  2010-02-17       Air  Conditioners       NaN  Toshino  2369.33
# 157  2010-02-18       Air  Conditioners       NaN  Toshino  2214.00
# 205  2010-02-19       Air  Conditioners       NaN  Toshino  2224.00
# 248  2010-02-22       Air  Conditioners       NaN  Toshino  2226.00
# 288  2010-02-23       Air  Conditioners       NaN  Toshino  2243.00
# 328  2010-02-24       Air  Conditioners       NaN  Toshino  2369.33
# 391  2010-02-25       Air  Conditioners       NaN  Toshino  2220.00
# 431  2010-03-01       Air  Conditioners       NaN  Toshino  2216.00
# 481  2010-03-02       Air  Conditioners       NaN  Toshino  2211.00
# 502  2010-03-03       Air  Conditioners       NaN  Toshino  2177.00
# 541  2010-03-04       Air  Conditioners       NaN  Toshino  2204.00
# 588  2010-03-05       Air  Conditioners       NaN  Toshino  2182.00
# 618  2010-03-08       Air  Conditioners       NaN  Toshino  2241.00
# 661  2010-03-09       Air  Conditioners       NaN  Toshino  2289.00
# 712  2010-03-10       Air  Conditioners       NaN  Toshino  2369.33
# 760  2010-03-11       Air  Conditioners       NaN  Toshino  2353.00
# 834  2010-03-12       Air  Conditioners       NaN  Toshino  2328.00
# 865  2010-03-15       Air  Conditioners       NaN  Toshino  2372.00
# 917  2010-03-17       Air  Conditioners       NaN  Toshino  2455.00
# 959  2010-03-18       Air  Conditioners       NaN  Toshino  2369.33
# 1004 2010-03-19       Air  Conditioners       NaN  Toshino  2574.00
# 1042 2010-03-22       Air  Conditioners       NaN  Toshino  2476.00
# 1058 2010-03-23       Air  Conditioners       NaN  Toshino  2545.00
# 1124 2010-03-24       Air  Conditioners       NaN  Toshino  2677.00
# 1184 2010-03-25       Air  Conditioners       NaN  Toshino  2648.00
# 1204 2010-03-26       Air  Conditioners       NaN  Toshino  2660.00
# 1266 2010-03-29       Air  Conditioners       NaN  Toshino  2639.00
# 1310 2010-03-30       Air  Conditioners       NaN  Toshino  2685.00
# 1361 2010-03-31       Air  Conditioners       NaN  Toshino  2606.00
#
#       Identifier
# 0     RVFWTWSMNU
# 82    RVFWTWSMNU
# 129   RVFWTWSMNU
# 157   RVFWTWSMNU
# 205   RVFWTWSMNU
# 248   RVFWTWSMNU
# 288   RVFWTWSMNU
# 328   RVFWTWSMNU
# 391   RVFWTWSMNU
# 431   RVFWTWSMNU
# 481   RVFWTWSMNU
# 502   RVFWTWSMNU
# 541   RVFWTWSMNU
# 588   RVFWTWSMNU
# 618   RVFWTWSMNU
# 661   RVFWTWSMNU
# 712   RVFWTWSMNU
# 760   RVFWTWSMNU
# 834   RVFWTWSMNU
# 865   RVFWTWSMNU
# 917   RVFWTWSMNU
# 959   RVFWTWSMNU
# 1004  RVFWTWSMNU
# 1042  RVFWTWSMNU
# 1058  RVFWTWSMNU
# 1124  RVFWTWSMNU
# 1184  RVFWTWSMNU
# 1204  RVFWTWSMNU
# 1266  RVFWTWSMNU
# 1310  RVFWTWSMNU
# 1361  RVFWTWSMNU

# %%
y10_1[(y10_1['Sales'].isnull()) & (y10_1['Identifier'] == 'RVFWTWSMNU')]
# Out:
#            Date Category1     Category2 Category3    Maker  Sales  Identifier
# 129  2010-02-17       Air  Conditioners       NaN  Toshino    NaN  RVFWTWSMNU
# 328  2010-02-24       Air  Conditioners       NaN  Toshino    NaN  RVFWTWSMNU
# 712  2010-03-10       Air  Conditioners       NaN  Toshino    NaN  RVFWTWSMNU
# 959  2010-03-18       Air  Conditioners       NaN  Toshino    NaN  RVFWTWSMNU

# %%
df2
# Out:
#              Date      Category1     Category2 Category3      Maker    Sales  \
# 0      2010-02-15            Air  Conditioners       NaN    Toshino   2143.0
# 1      2010-02-15          Water       Heaters       NaN   Furutani    567.0
# 2      2010-02-15        Washers             &    Dryers      Akaza   3515.0
# 3      2010-02-15  Refrigerators           NaN       NaN      Akaza    687.0
# 4      2010-02-15        Washers             &    Dryers    Shimada    435.0
# ...           ...            ...           ...       ...        ...      ...
# 134959 2021-04-29            Air  Conditioners       NaN      Akaza   1609.0
# 134960 2021-04-29        Washers             &    Dryers      Akaza   5422.0
# 134961 2021-04-29         Vacuum      Cleaners       NaN  Hayashida    539.0
# 134962 2021-04-29          Water         Pumps       NaN   Furutani  10547.0
# 134963 2021-04-29    Televisions           NaN       NaN     Kikuma    805.0
#
#         Identifier
# 0       RVFWTWSMNU
# 1       PF4KB33DVZ
# 2       VUQUQMHODG
# 3       XVIOZZOUTN
# 4       RBRMDIXXGL
# ...            ...
# 134959  IVOI4I03JA
# 134960  VUQUQMHODG
# 134961  GCPKFKSEWG
# 134962  FVDHIZGQRC
# 134963  FRBLLORNXN
#
# [134964 rows x 7 columns]
