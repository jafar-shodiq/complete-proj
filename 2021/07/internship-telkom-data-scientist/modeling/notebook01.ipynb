# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# import warnings
# warnings.filterwarnings('ignore')

# %%
df0 = pd.read_feather('D:/big-datasets/internship-telkom/training_df_feature/CW17_feature_0_30m.ftr')

# %%
df0
# Out:
#                                                 user_id  level_1  \
# 0     010e0ba3feb281af50f84cf90bf3b2539ddae52c243b2a...        0
# 1     010e0ba3feb281af50f84cf90bf3b2539ddae52c243b2a...        1
# 2     010e0ba3feb281af50f84cf90bf3b2539ddae52c243b2a...        2
# 3     010e0ba3feb281af50f84cf90bf3b2539ddae52c243b2a...        3
# 4     010e0ba3feb281af50f84cf90bf3b2539ddae52c243b2a...        4
# ...                                                 ...      ...
# 6828  ffe56aa85cc3788f18822534c2d18f5e01a28254097079...        5
# 6829  ffe56aa85cc3788f18822534c2d18f5e01a28254097079...        6
# 6830  ffe56aa85cc3788f18822534c2d18f5e01a28254097079...        7
# 6831  ffe56aa85cc3788f18822534c2d18f5e01a28254097079...        8
# 6832  ffe56aa85cc3788f18822534c2d18f5e01a28254097079...        9
#
#                date_time reg cwitel speed_id  device_count_01  \
# 0    2021-06-02 21:30:00   2     17      20M              5.0
# ...

# %%
df0.columns
# Out:
# Index(['user_id', 'level_1', 'date_time', 'reg', 'cwitel', 'speed_id',
#        'device_count_01', 'device_count_02', 'device_count_03',
#        'device_count_04',
#        ...
#        'ser_acces_score_90', 'ser_acces_score_91', 'ser_acces_score_92',
#        'ser_acces_score_93', 'ser_acces_score_94', 'ser_acces_score_95',
#        'ser_acces_score_96', 'y', 'dth_', 'nacount'],
#       dtype='object', length=1833)

# %%
df1 = pd.read_feather('D:/big-datasets/internship-telkom/training_df_feature/CW17_feature_1_30m.ftr')

# %%
df1
# Out:
#      device_count_01  device_count_02  device_count_03  device_count_04  \
# 0                4.0              2.0              4.0              2.0
# 1               72.0             74.0             65.0             71.0
# 2                3.0              3.0              5.0              4.0
# 3                1.0              1.0              1.0              1.0
# 4                1.0              1.0              1.0              1.0
# ..               ...              ...              ...              ...
# 693              4.0              3.0              2.0              2.0
# 694              4.0              4.0              4.0              6.0
# 695              5.0              1.0              NaN              NaN
# 696              3.0              5.0              3.0              4.0
# 697              1.0              3.0              NaN              NaN
#
#      device_count_05  device_count_06  device_count_07  device_count_08  \
# ...

# %%
df0['y'].value_counts(bins=10).sort_index()
# Out:
# (-632.351, -496.0]     786
# (-496.0, -361.0]       689
# (-361.0, -226.0]      1077
# (-226.0, -91.0]        715
# (-91.0, 44.0]            0
# (44.0, 179.0]          299
# (179.0, 314.0]        1148
# (314.0, 449.0]         804
# (449.0, 584.0]         627
# (584.0, 719.0]         688
# Name: y, dtype: int64

# %%
dfa = pd.read_feather('D:/big-datasets/internship-telkom/Archive 3/CW14_feature_0_30m.ftr')
dfb = pd.read_feather('D:/big-datasets/internship-telkom/Archive 3/CW14_feature_1_30m.ftr')

# %%
dfa
# Out:
#                                                 user_id  level_1  \
# 0     007363effc070e5cb5198f8fe336c26dc92c628ca2beac...        0
# 1     007363effc070e5cb5198f8fe336c26dc92c628ca2beac...        1
# 2     007363effc070e5cb5198f8fe336c26dc92c628ca2beac...        2
# 3     007363effc070e5cb5198f8fe336c26dc92c628ca2beac...        3
# 4     007363effc070e5cb5198f8fe336c26dc92c628ca2beac...        4
# ...                                                 ...      ...
# 6016  ffd6e71fd7cfdf88b04ee2c31af359027b7d133fb23564...        5
# 6017  ffd6e71fd7cfdf88b04ee2c31af359027b7d133fb23564...        6
# 6018  ffd6e71fd7cfdf88b04ee2c31af359027b7d133fb23564...        7
# 6019  ffd6e71fd7cfdf88b04ee2c31af359027b7d133fb23564...        8
# 6020  ffd6e71fd7cfdf88b04ee2c31af359027b7d133fb23564...        9
#
#                date_time reg cwitel speed_id  device_count_01  \
# 0    2021-05-20 13:30:00   2     14      20M              5.0
# ...

# %%
dfb
# Out:
#      device_count_01  device_count_02  device_count_03  device_count_04  \
# 0                4.0              3.0              NaN              NaN
# 1                NaN              2.0              NaN              NaN
# 2                NaN              NaN              NaN              NaN
# 3                7.0              6.0              6.0              5.0
# 4                6.0              5.0              4.0              3.0
# ..               ...              ...              ...              ...
# 581              2.0              1.0              1.0              2.0
# 582              6.0              7.0              6.0             10.0
# 583              NaN              NaN              NaN              NaN
# 584              2.0              3.0              2.0              3.0
# 585              7.0              6.0              4.0              3.0
#
#      device_count_05  device_count_06  device_count_07  device_count_08  \
# ...

# %%
df0[(df0['y'] > 1) & (df0['y'] < 48)]
# Out:
# Empty DataFrame
# ...

# %%
df0[(df0['y'] > 48)]
# Out:
#                                                 user_id  level_1  \
# 1     010e0ba3feb281af50f84cf90bf3b2539ddae52c243b2a...        1
# 2     010e0ba3feb281af50f84cf90bf3b2539ddae52c243b2a...        2
# 3     010e0ba3feb281af50f84cf90bf3b2539ddae52c243b2a...        3
# 4     010e0ba3feb281af50f84cf90bf3b2539ddae52c243b2a...        4
# 5     010e0ba3feb281af50f84cf90bf3b2539ddae52c243b2a...        5
# ...                                                 ...      ...
# 6818  ffc7edfe565682412aa8a9b23157da8019a5a91714db86...        5
# 6819  ffc7edfe565682412aa8a9b23157da8019a5a91714db86...        6
# 6823  ffe56aa85cc3788f18822534c2d18f5e01a28254097079...        0
# 6826  ffe56aa85cc3788f18822534c2d18f5e01a28254097079...        3
# 6828  ffe56aa85cc3788f18822534c2d18f5e01a28254097079...        5
#
#                date_time reg cwitel speed_id  device_count_01  \
# 1    2021-06-09 23:00:00   2     17      20M              4.0
# ...

# %%
df0[(df0['y'] < -1) & (df0['y'] > -48)]
# Out:
# Empty DataFrame
# ...
